# %% [markdown]
# # Label classifier (dSprites): results
#
# ## Task 2
#
# **Author**: Maleakhi A. Wijaya
# **Description**: This notebook contains code used to visualise experimentation results for the dSprites dataset. In this file, we focus on task 2: end task to predict the combination of shape and scale of the sprites.

# %%
# Load utilities functions
# %run ../../scripts/constants.py
# %run ../../scripts/dsprites_utils.py
# %run ../../scripts/shift_applicator.py
# %run ../../scripts/shift_dimensionality_reductor.py
# %run ../../scripts/experiment_utils.py
# %run ../../scripts/shift_statistical_test.py

# %% [markdown]
# ## Tables
#
# The tables depict detection accuracy for different sample number against varying shift intensities and shift proportions.

# %%
list_shifts = ["Knockout", "Concept (Scale)", "Concept (Shape + Scale)",
              "Concept (X)", "Concept (Y)", "Concept (X + Y)", "Concept (X + Y + Scale)",
              "Translation (X)", "Translation (Y)", "Shear", "Zoom", "Rotation", "All", "Gaussian"]
list_labels = ["CBSDs", "CBSDh", "UAE", "TAE", 
              "BBSDs", "BBSDh", "PCA", "SRP"]
list_is_concepts = [True, True, False, False,
                   False, False, False, False]
list_shift_str = ["ko_task2", "scale_task2", "scale_shape_task2", "x_task2", "y_task2", 
                  "x_y_task2", "x_y_scale_task2", "img_x_task2", "img_y_task2",
                 "shear_task2", "zoom_task2", "rotation_task2", "all_task2", "gaussian_task2"]

# %% [markdown]
# ### Knockout shift

# %%
for shift, shift_str in zip(list_shifts[:1], list_shift_str[:1]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout
# ## Method: CBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.010000  0.023333  0.020000  0.026667  0.046667  0.026667  0.020000
# Medium  0.006667  0.020000  0.013333  0.010000  0.036667  0.036667  0.056667
# Large   0.013333  0.030000  0.040000  0.050000  0.120000  0.333333  0.763333
#
#         10000
# Small    0.00
# Medium   0.99
# Large    1.00
# *Shift proportion vs. # of samples*
#       10        20        50        100       200       500       1000   \
# 10%    0.01  0.023333  0.026667  0.023333  0.063333  0.130000  0.263333
# 50%    0.01  0.023333  0.026667  0.030000  0.076667  0.103333  0.280000
# 100%   0.01  0.026667  0.020000  0.033333  0.063333  0.163333  0.296667
#
#          10000
# 10%   0.663333
# 50%   0.663333
# 100%  0.663333
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
# ...

# %% [markdown]
# ### Concept shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = [ "BBSDs", "BBSDh"]
list_is_concepts = [False, False]

# %% [markdown]
# - Scale
# - Shape and scale
# - X
# - Y
# - X and Y
# - X and Y and scale

# %%
for shift, shift_str in zip(list_shifts[1:7], list_shift_str[1:7]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Scale)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.000000  0.023333  0.013333  0.016667  0.016667  0.013333  0.013333
# Medium  0.000000  0.010000  0.013333  0.016667  0.026667  0.163333  0.516667
# Large   0.006667  0.033333  0.046667  0.216667  0.560000  0.966667  1.000000
#
#         10000
# Small    0.01
# Medium   1.00
# Large    1.00
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.003333  0.033333  0.026667  0.080000  0.200000  0.380000  0.513333
# 50%   0.003333  0.023333  0.016667  0.076667  0.206667  0.370000  0.510000
# 100%  0.000000  0.010000  0.030000  0.093333  0.196667  0.393333  0.506667
#
#          10000
# 10%   0.676667
# 50%   0.666667
# 100%  0.666667
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
# ...

# %% [markdown]
# ### Image shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = [ "BBSDs", "BBSDh"]
list_is_concepts = [False, False]

# %% [markdown]
# - Translation (X)
# - Translation (Y)
# - Shear
# - Zoom
# - Rotation
# - All

# %%
for shift, shift_str in zip(list_shifts[7:13], list_shift_str[7:13]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.006667  0.020000  0.020000  0.020000  0.033333  0.026667
# Medium  0.013333  0.020000  0.026667  0.073333  0.133333  0.313333  0.453333
# Large   0.020000  0.060000  0.173333  0.393333  0.480000  0.660000  0.673333
#
#            10000
# Small   0.333333
# Medium  0.666667
# Large   0.700000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.006667  0.013333  0.000000  0.040000  0.006667  0.026667  0.013333
# 50%   0.000000  0.026667  0.053333  0.093333  0.173333  0.353333  0.446667
# 100%  0.033333  0.046667  0.166667  0.353333  0.453333  0.626667  0.693333
#
#          10000
# 10%   0.033333
# 50%   0.666667
# 100%  1.000000
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
# ...

# %% [markdown]
# ### Gaussian shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = [ "BBSDs", "BBSDh"]
list_is_concepts = [False, False]

# %%
for shift, shift_str in zip(list_shifts[13:14], list_shift_str[13:14]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200    500       1000   \
# Small   0.006667  0.013333  0.026667  0.033333  0.013333   0.04  0.046667
# Medium  0.133333  0.273333  0.466667  0.646667  0.680000   0.68  0.726667
# Large   0.500000  0.666667  0.693333  0.746667  0.840000   1.00  1.000000
#
#            10000
# Small   0.326667
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200    500       1000   \
# 10%   0.026667  0.000000  0.033333  0.093333  0.186667   0.36  0.400000
# 50%   0.166667  0.380000  0.466667  0.653333  0.666667   0.68  0.673333
# 100%  0.446667  0.573333  0.686667  0.680000  0.680000   0.68  0.700000
#
#          10000
# 10%   0.666667
# 50%   0.673333
# 100%  0.986667
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
# ...

# %% [markdown]
# ## Detection accuracy vs test samples
#
# The figures plot how detection accuracy changes over different test (real-world) samples provided to each shift detector method. We compare performances of various methods.

# %%
list_shifts = ["Knockout", "Concept (Scale)", "Concept (Shape + Scale)",
              "Concept (X)", "Concept (Y)", "Concept (X + Y)", "Concept (X + Y + Scale)",
              "Translation (X)", "Translation (Y)", "Shear", "Zoom", "Rotation", "All", "Gaussian"]
list_labels = ["CBSDs", "CBSDh", "UAE", "TAE", 
              "BBSDs", "BBSDh", "PCA", "SRP"]
list_is_concepts = [True, True, False, False,
                   False, False, False, False]
list_shift_str = ["ko_task2", "scale_task2", "scale_shape_task2", "x_task2", "y_task2", 
                  "x_y_task2", "x_y_scale_task2", "img_x_task2", "img_y_task2",
                 "shear_task2", "zoom_task2", "rotation_task2", "all_task2", "gaussian_task2"]

# %% [markdown]
# ### Knockout shift

# %%
for shift, shift_str in zip(list_shifts[:1], list_shift_str[:1]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout

# %% [markdown]
# ### Concept shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "scale", "scale_shape", "x", "y", "x_y", "x_y_scale", "img_x", "img_y",
                 "shear", "zoom", "rotation", "all"]

# %% [markdown]
# - Scale
# - Shape and scale
# - X
# - Y
# - X and Y
# - X and Y and scale

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[1:7], list_shift_str_1[1:7], list_shift_str_2[1:7]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False))
        except:
            list_dict_results.append(load_result(shift_str1, label, False))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Scale)
# # Concept (Shape + Scale)
# # Concept (X)
# # Concept (Y)
# # Concept (X + Y)
# # Concept (X + Y + Scale)

# %% [markdown]
# ### Image shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "scale", "scale_shape", "x", "y", "x_y", "x_y_scale", "img_x", "img_y",
                 "shear", "zoom", "rotation", "all", "gaussian"]

# %% [markdown]
# - Translation (X)
# - Translation (Y)
# - Shear
# - Zoom
# - Rotation
# - All

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[7:13], list_shift_str_1[7:13], list_shift_str_2[7:13]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False))
        except:
            list_dict_results.append(load_result(shift_str1, label, False))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# # Translation (Y)
# # Shear
# # Zoom
# # Rotation
# # All

# %% [markdown]
# ### Gaussian shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "scale", "scale_shape", "x", "y", "x_y", "x_y_scale", "img_x", "img_y",
                 "shear", "zoom", "rotation", "all", "gaussian"]

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[13:14], list_shift_str_1[13:14], list_shift_str_2[13:14]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False))
        except:
            list_dict_results.append(load_result(shift_str1, label, False))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian

# %% [markdown]
# ## Barplot explanations
#
# The barplots depict the degree how each concept is affected by various type of shifts. Higher value indicates that the concept is more shifted relative to others.

# %%
list_shifts = ["Knockout"]
list_labels = ["CBSDs", "CBSDh"]
list_shift_str = ["ko_task2"]
list_dict_results = []
for shift_str in list_shift_str:
    temp = []
    for label in list_labels:
        temp.append(load_result(shift_str, label, False))
    list_dict_results.append(temp)

list_shift_intensity = [ShiftIntensity.Large]
list_shift_prop = [1.0]
list_test_sample = [1000, 10000]
concept_names = ["color", "shape", "scale", "rotation", "x", "y"]

# %%
for shift, dict_result in zip(list_shifts, list_dict_results):
    display(Markdown(f"# {shift}"))
    
    dict_cbsds = dict_result[0]
    dict_cbsdh = dict_result[1]
    
    barplot_test_statistics(dict_cbsds, dict_cbsdh,
                           concept_names, list_shift_intensity,
                           list_shift_prop, list_test_sample)
# Out:
# # Knockout
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 1000
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 10000
