# %% [markdown]
# # Label classifier (dSprites): results
#
# ## Task 3
#
# **Author**: Maleakhi A. Wijaya
# **Description**: This notebook contains code used to visualise experimentation results for the dSprites dataset. In this file, we focus on task 3: end task to predict the binary clusters of concept 'x'.

# %%
# Load utilities functions
# %run ../../scripts/constants.py
# %run ../../scripts/dsprites_utils.py
# %run ../../scripts/shift_applicator.py
# %run ../../scripts/shift_dimensionality_reductor.py
# %run ../../scripts/experiment_utils.py
# %run ../../scripts/shift_statistical_test.py

# %% [markdown]
# ## Tables
#
# The tables depict detection accuracy for different sample number against varying shift intensities and shift proportions.

# %%
list_shifts = ["Knockout", "Concept (Scale)", "Concept (Shape + Scale)",
              "Concept (X)", "Concept (Y)", "Concept (X + Y)", "Concept (X + Y + Scale)",
              "Translation (X)", "Translation (Y)", "Shear", "Zoom", "Rotation", "All", "Gaussian"]
list_labels = ["CBSDs", "CBSDh", "UAE", "TAE", 
              "BBSDs", "BBSDh", "PCA", "SRP"]
list_is_concepts = [True, True, False, False,
                   False, False, False, False]
list_shift_str = ["ko_task3", "scale_task3", "scale_shape_task3", "x_task3", "y_task3", 
                  "x_y_task3", "x_y_scale_task3", "img_x_task3", "img_y_task3",
                 "shear_task3", "zoom_task3", "rotation_task3", "all_task3", "gaussian_task3"]

# %% [markdown]
# ### Knockout shift

# %%
list_dict_results = []
for shift_str in list_shift_str[:1]:
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[:1]:
    display(Markdown(f"# {shift}"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout
# ## Method: CBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.030000  0.030000  0.023333  0.046667  0.036667  0.060000  0.076667
# Medium  0.036667  0.023333  0.033333  0.036667  0.046667  0.070000  0.086667
# Large   0.013333  0.036667  0.046667  0.030000  0.156667  0.873333  1.000000
#
#            10000
# Small   0.013333
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.036667  0.030000  0.030000  0.020000  0.093333  0.330000  0.390000
# 50%   0.016667  0.036667  0.033333  0.060000  0.070000  0.333333  0.376667
# 100%  0.026667  0.023333  0.040000  0.033333  0.076667  0.340000  0.396667
#
#          10000
# 10%   0.676667
# 50%   0.666667
# 100%  0.670000
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.243333  0.213333  0.196667  0.233333  0.240000  0.266667  0.266667
# Medium  0.200000  0.220000  0.206667  0.286667  0.383333  0.820000  1.000000
# Large   0.213333  0.270000  0.606667  0.966667  1.000000  1.000000  1.000000
#
#         10000
# Small    0.42
# Medium   1.00
# Large    1.00
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.256667  0.230000  0.310000  0.506667  0.556667  0.686667  0.760000
# 50%   0.226667  0.243333  0.346667  0.453333  0.543333  0.690000  0.760000
# 100%  0.173333  0.230000  0.353333  0.526667  0.523333  0.710000  0.746667
#
#          10000
# 10%   0.803333
# 50%   0.813333
# 100%  0.803333
# ## Method: UAE
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.003333  0.013333  0.000000  0.010000  0.010000  0.000000  0.006667
# Medium  0.000000  0.013333  0.313333  0.190000  0.190000  0.050000  0.106667
# Large   0.000000  0.010000  0.080000  0.276667  0.276667  0.596667  0.950000
#
#            10000
# Small   0.053333
# Medium  0.776667
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.003333  0.013333  0.146667  0.166667  0.166667  0.236667  0.350000
# 50%   0.000000  0.016667  0.143333  0.143333  0.143333  0.210000  0.366667
# 100%  0.000000  0.006667  0.103333  0.166667  0.166667  0.200000  0.346667
#
#          10000
# 10%   0.610000
# 50%   0.633333
# 100%  0.586667
# ## Method: TAE
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.003333  0.003333  0.003333  0.003333  0.150000  0.010000  0.003333
# Medium  0.093333  0.093333  0.093333  0.093333  0.093333  0.053333  0.123333
# Large   0.093333  0.093333  0.370000  0.370000  0.370000  0.660000  0.966667
#
#            10000
# Small   0.016667
# Medium  0.936667
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.073333  0.073333  0.146667  0.146667  0.203333  0.253333  0.366667
# 50%   0.066667  0.066667  0.186667  0.186667  0.230000  0.226667  0.363333
# 100%  0.050000  0.050000  0.133333  0.133333  0.180000  0.243333  0.363333
#
#          10000
# 10%   0.663333
# 50%   0.650000
# 100%  0.640000
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.010000  0.013333  0.000000  0.010000  0.003333  0.006667  0.003333
# Medium  0.006667  0.006667  0.036667  0.276667  0.873333  1.000000  1.000000
# Large   0.066667  0.583333  1.000000  1.000000  1.000000  1.000000  1.000000
#
#            10000
# Small   0.956667
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.016667  0.196667  0.350000  0.426667  0.613333  0.670000  0.666667
# 50%   0.040000  0.210000  0.340000  0.420000  0.630000  0.670000  0.670000
# 100%  0.026667  0.196667  0.346667  0.440000  0.633333  0.666667  0.666667
#
#          10000
# 10%   0.986667
# 50%   0.986667
# 100%  0.983333
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200    500       1000   \
# Small   0.020000  0.020000  0.016667  0.010000  0.003333   0.01  0.003333
# Medium  0.000000  0.003333  0.046667  0.466667  0.946667   1.00  1.000000
# Large   0.523333  0.776667  1.000000  1.000000  1.000000   1.00  1.000000
#
#         10000
# Small     1.0
# Medium    1.0
# Large     1.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.140000  0.273333  0.353333  0.483333  0.650000  0.673333  0.666667
# 50%   0.200000  0.263333  0.350000  0.486667  0.653333  0.670000  0.670000
# 100%  0.203333  0.263333  0.360000  0.506667  0.646667  0.666667  0.666667
#
#       10000
# 10%     1.0
# 50%     1.0
# 100%    1.0
# ## Method: PCA
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.056667  0.050000  0.076667  0.043333  0.066667  0.070000  0.080000
# Medium  0.070000  0.050000  0.046667  0.053333  0.050000  0.080000  0.203333
# Large   0.056667  0.073333  0.073333  0.100000  0.190000  0.543333  0.940000
#
#            10000
# Small   0.156667
# Medium  0.783333
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.053333  0.056667  0.063333  0.083333  0.103333  0.246667  0.390000
# 50%   0.063333  0.066667  0.053333  0.050000  0.100000  0.213333  0.403333
# 100%  0.066667  0.050000  0.080000  0.063333  0.103333  0.233333  0.430000
#
#          10000
# 10%   0.646667
# 50%   0.646667
# 100%  0.646667
# ## Method: SRP
# *Shift intensities vs. # of samples*
#            10     20        50        100       200       500       1000   \
# Small   0.006667   0.00  0.010000  0.003333  0.003333  0.006667  0.013333
# Medium  0.016667   0.01  0.006667  0.003333  0.020000  0.020000  0.060000
# Large   0.023333   0.02  0.020000  0.036667  0.116667  0.543333  0.956667
#
#            10000
# Small   0.003333
# Medium  0.943333
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.010000  0.013333  0.020000  0.013333  0.033333  0.183333  0.333333
# 50%   0.016667  0.003333  0.010000  0.023333  0.056667  0.216667  0.353333
# 100%  0.020000  0.013333  0.006667  0.006667  0.050000  0.170000  0.343333
#
#          10000
# 10%   0.653333
# 50%   0.640000
# 100%  0.653333

# %% [markdown]
# ### Concept shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = [ "BBSDs", "BBSDh"]
list_is_concepts = [False, False]

# %% [markdown]
# **- Scale**
# **- Shape + Scale**
# **- X**

# %%
list_dict_results = []
for shift_str in list_shift_str[1:4]:
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[1:4]:
    display(Markdown(f"# {shift}"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Scale)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.023333  0.020000  0.013333  0.016667  0.020000  0.003333  0.020000
# Medium  0.006667  0.013333  0.016667  0.026667  0.023333  0.010000  0.033333
# Large   0.010000  0.016667  0.033333  0.036667  0.026667  0.050000  0.070000
#
#            10000
# Small   0.000000
# Medium  0.003333
# Large   0.666667
# *Shift proportion vs. # of samples*
#       10        20        50        100       200       500       1000   \
# 10%    0.02  0.016667  0.030000  0.013333  0.013333  0.026667  0.050000
# 50%    0.01  0.016667  0.010000  0.040000  0.020000  0.016667  0.033333
# 100%   0.01  0.016667  0.023333  0.026667  0.036667  0.020000  0.040000
#
#          10000
# 10%   0.216667
# 50%   0.206667
# 100%  0.246667
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.036667  0.000000  0.016667  0.020000  0.036667  0.036667  0.030000
# Medium  0.010000  0.026667  0.033333  0.036667  0.030000  0.033333  0.050000
# Large   0.026667  0.026667  0.020000  0.023333  0.030000  0.040000  0.036667
#
#            10000
# Small   0.000000
# Medium  0.000000
# Large   0.003333
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.020000  0.013333  0.026667  0.036667  0.010000  0.026667  0.043333
# 50%   0.023333  0.016667  0.016667  0.016667  0.046667  0.036667  0.043333
# 100%  0.030000  0.023333  0.026667  0.026667  0.040000  0.046667  0.030000
#
#          10000
# 10%   0.000000
# 50%   0.000000
# 100%  0.003333
# # Concept (Shape + Scale)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.023333  0.020000  0.013333  0.016667  0.020000  0.003333  0.020000
# Medium  0.006667  0.013333  0.016667  0.026667  0.023333  0.010000  0.033333
# Large   0.010000  0.016667  0.033333  0.036667  0.026667  0.050000  0.070000
#
#            10000
# Small   0.000000
# Medium  0.003333
# Large   0.666667
# *Shift proportion vs. # of samples*
#       10        20        50        100       200       500       1000   \
# 10%    0.02  0.016667  0.030000  0.013333  0.013333  0.026667  0.050000
# 50%    0.01  0.016667  0.010000  0.040000  0.020000  0.016667  0.033333
# 100%   0.01  0.016667  0.023333  0.026667  0.036667  0.020000  0.040000
#
#          10000
# 10%   0.216667
# 50%   0.206667
# 100%  0.246667
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.036667  0.000000  0.016667  0.020000  0.036667  0.036667  0.030000
# Medium  0.010000  0.026667  0.033333  0.036667  0.030000  0.033333  0.050000
# Large   0.026667  0.026667  0.020000  0.023333  0.030000  0.040000  0.036667
#
#            10000
# Small   0.000000
# Medium  0.000000
# Large   0.003333
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.020000  0.013333  0.026667  0.036667  0.010000  0.026667  0.043333
# 50%   0.023333  0.016667  0.016667  0.016667  0.046667  0.036667  0.043333
# 100%  0.030000  0.023333  0.026667  0.026667  0.040000  0.046667  0.030000
#
#          10000
# 10%   0.000000
# 50%   0.000000
# 100%  0.003333
# # Concept (X)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.023333  0.020000  0.013333  0.016667  0.020000  0.003333  0.020000
# Medium  0.006667  0.013333  0.016667  0.026667  0.023333  0.010000  0.033333
# Large   0.010000  0.016667  0.033333  0.036667  0.026667  0.050000  0.070000
#
#            10000
# Small   0.000000
# Medium  0.003333
# Large   0.666667
# *Shift proportion vs. # of samples*
#       10        20        50        100       200       500       1000   \
# 10%    0.02  0.016667  0.030000  0.013333  0.013333  0.026667  0.050000
# 50%    0.01  0.016667  0.010000  0.040000  0.020000  0.016667  0.033333
# 100%   0.01  0.016667  0.023333  0.026667  0.036667  0.020000  0.040000
#
#          10000
# 10%   0.216667
# 50%   0.206667
# 100%  0.246667
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.036667  0.000000  0.016667  0.020000  0.036667  0.036667  0.030000
# Medium  0.010000  0.026667  0.033333  0.036667  0.030000  0.033333  0.050000
# Large   0.026667  0.026667  0.020000  0.023333  0.030000  0.040000  0.036667
#
#            10000
# Small   0.000000
# Medium  0.000000
# Large   0.003333
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.020000  0.013333  0.026667  0.036667  0.010000  0.026667  0.043333
# 50%   0.023333  0.016667  0.016667  0.016667  0.046667  0.036667  0.043333
# 100%  0.030000  0.023333  0.026667  0.026667  0.040000  0.046667  0.030000
#
#          10000
# 10%   0.000000
# 50%   0.000000
# 100%  0.003333

# %% [markdown]
# **- Y**
# **- X + Y**
# **- X + Y + Scale**

# %%
list_dict_results = []
for shift_str in list_shift_str[4:7]:
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[4:7]:
    display(Markdown(f"# {shift}"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Y)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.016667  0.020000  0.020000  0.023333  0.020000  0.016667  0.026667
# Medium  0.013333  0.020000  0.010000  0.023333  0.016667  0.026667  0.020000
# Large   0.020000  0.033333  0.006667  0.020000  0.020000  0.030000  0.010000
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.023333  0.030000  0.013333  0.020000  0.016667  0.023333  0.036667
# 50%   0.016667  0.016667  0.013333  0.016667  0.016667  0.026667  0.006667
# 100%  0.010000  0.026667  0.010000  0.030000  0.023333  0.023333  0.013333
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50     100       200       500       1000   \
# Small   0.033333  0.020000  0.020000   0.03  0.030000  0.040000  0.040000
# Medium  0.033333  0.020000  0.026667   0.04  0.030000  0.036667  0.030000
# Large   0.016667  0.023333  0.040000   0.04  0.053333  0.026667  0.033333
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.030000  0.006667  0.030000  0.060000  0.056667  0.033333  0.033333
# 50%   0.023333  0.033333  0.043333  0.023333  0.036667  0.033333  0.036667
# 100%  0.030000  0.023333  0.013333  0.026667  0.020000  0.036667  0.033333
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# # Concept (X + Y)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.016667  0.020000  0.020000  0.023333  0.020000  0.016667  0.026667
# Medium  0.013333  0.020000  0.010000  0.023333  0.016667  0.026667  0.020000
# Large   0.020000  0.033333  0.006667  0.020000  0.020000  0.030000  0.010000
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.023333  0.030000  0.013333  0.020000  0.016667  0.023333  0.036667
# 50%   0.016667  0.016667  0.013333  0.016667  0.016667  0.026667  0.006667
# 100%  0.010000  0.026667  0.010000  0.030000  0.023333  0.023333  0.013333
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50     100       200       500       1000   \
# Small   0.033333  0.020000  0.020000   0.03  0.030000  0.040000  0.040000
# Medium  0.033333  0.020000  0.026667   0.04  0.030000  0.036667  0.030000
# Large   0.016667  0.023333  0.040000   0.04  0.053333  0.026667  0.033333
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.030000  0.006667  0.030000  0.060000  0.056667  0.033333  0.033333
# 50%   0.023333  0.033333  0.043333  0.023333  0.036667  0.033333  0.036667
# 100%  0.030000  0.023333  0.013333  0.026667  0.020000  0.036667  0.033333
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# # Concept (X + Y + Scale)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.016667  0.020000  0.020000  0.023333  0.020000  0.016667  0.026667
# Medium  0.013333  0.020000  0.010000  0.023333  0.016667  0.026667  0.020000
# Large   0.020000  0.033333  0.006667  0.020000  0.020000  0.030000  0.010000
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.023333  0.030000  0.013333  0.020000  0.016667  0.023333  0.036667
# 50%   0.016667  0.016667  0.013333  0.016667  0.016667  0.026667  0.006667
# 100%  0.010000  0.026667  0.010000  0.030000  0.023333  0.023333  0.013333
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50     100       200       500       1000   \
# Small   0.033333  0.020000  0.020000   0.03  0.030000  0.040000  0.040000
# Medium  0.033333  0.020000  0.026667   0.04  0.030000  0.036667  0.030000
# Large   0.016667  0.023333  0.040000   0.04  0.053333  0.026667  0.033333
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.030000  0.006667  0.030000  0.060000  0.056667  0.033333  0.033333
# 50%   0.023333  0.033333  0.043333  0.023333  0.036667  0.033333  0.036667
# 100%  0.030000  0.023333  0.013333  0.026667  0.020000  0.036667  0.033333
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0

# %% [markdown]
# ### Image shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = [ "BBSDs", "BBSDh"]
list_is_concepts = [False, False]

# %% [markdown]
# **- Translation (X)**
# **- Translation (Y)**
# **- Shear**

# %%
list_dict_results = []
for shift_str in list_shift_str[7:10]:
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[7:10]:
    display(Markdown(f"# {shift}"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.006667  0.013333  0.053333  0.186667  0.346667  0.433333
# Medium  0.013333  0.033333  0.066667  0.113333  0.206667  0.400000  0.546667
# Large   0.040000  0.060000  0.166667  0.326667  0.453333  0.673333  0.686667
#
#            10000
# Small   0.666667
# Medium  0.673333
# Large   0.806667
# *Shift proportion vs. # of samples*
#       10        20        50        100       200    500       1000      10000
# 10%    0.02  0.026667  0.026667  0.013333  0.020000   0.04  0.020000  0.146667
# 50%    0.02  0.046667  0.040000  0.113333  0.186667   0.50  0.646667  1.000000
# 100%   0.02  0.026667  0.180000  0.366667  0.640000   0.88  1.000000  1.000000
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.033333  0.020000  0.020000  0.053333  0.046667  0.006667  0.020000
# Medium  0.033333  0.046667  0.066667  0.086667  0.133333  0.213333  0.446667
# Large   0.006667  0.080000  0.180000  0.360000  0.493333  0.640000  0.700000
#
#            10000
# Small   0.006667
# Medium  0.666667
# Large   0.780000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.026667  0.040000  0.026667  0.026667  0.060000  0.033333  0.073333
# 50%   0.026667  0.026667  0.046667  0.106667  0.180000  0.326667  0.440000
# 100%  0.020000  0.080000  0.193333  0.366667  0.433333  0.500000  0.653333
#
#          10000
# 10%   0.113333
# 50%   0.673333
# 100%  0.666667
# # Translation (Y)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.006667  0.013333  0.053333  0.186667  0.346667  0.433333
# Medium  0.013333  0.033333  0.066667  0.113333  0.206667  0.400000  0.546667
# Large   0.040000  0.060000  0.166667  0.326667  0.453333  0.673333  0.686667
#
#            10000
# Small   0.666667
# Medium  0.673333
# Large   0.806667
# *Shift proportion vs. # of samples*
#       10        20        50        100       200    500       1000      10000
# 10%    0.02  0.026667  0.026667  0.013333  0.020000   0.04  0.020000  0.146667
# 50%    0.02  0.046667  0.040000  0.113333  0.186667   0.50  0.646667  1.000000
# 100%   0.02  0.026667  0.180000  0.366667  0.640000   0.88  1.000000  1.000000
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.033333  0.020000  0.020000  0.053333  0.046667  0.006667  0.020000
# Medium  0.033333  0.046667  0.066667  0.086667  0.133333  0.213333  0.446667
# Large   0.006667  0.080000  0.180000  0.360000  0.493333  0.640000  0.700000
#
#            10000
# Small   0.006667
# Medium  0.666667
# Large   0.780000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.026667  0.040000  0.026667  0.026667  0.060000  0.033333  0.073333
# 50%   0.026667  0.026667  0.046667  0.106667  0.180000  0.326667  0.440000
# 100%  0.020000  0.080000  0.193333  0.366667  0.433333  0.500000  0.653333
#
#          10000
# 10%   0.113333
# 50%   0.673333
# 100%  0.666667
# # Shear
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.006667  0.013333  0.053333  0.186667  0.346667  0.433333
# Medium  0.013333  0.033333  0.066667  0.113333  0.206667  0.400000  0.546667
# Large   0.040000  0.060000  0.166667  0.326667  0.453333  0.673333  0.686667
#
#            10000
# Small   0.666667
# Medium  0.673333
# Large   0.806667
# *Shift proportion vs. # of samples*
#       10        20        50        100       200    500       1000      10000
# 10%    0.02  0.026667  0.026667  0.013333  0.020000   0.04  0.020000  0.146667
# 50%    0.02  0.046667  0.040000  0.113333  0.186667   0.50  0.646667  1.000000
# 100%   0.02  0.026667  0.180000  0.366667  0.640000   0.88  1.000000  1.000000
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.033333  0.020000  0.020000  0.053333  0.046667  0.006667  0.020000
# Medium  0.033333  0.046667  0.066667  0.086667  0.133333  0.213333  0.446667
# Large   0.006667  0.080000  0.180000  0.360000  0.493333  0.640000  0.700000
#
#            10000
# Small   0.006667
# Medium  0.666667
# Large   0.780000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.026667  0.040000  0.026667  0.026667  0.060000  0.033333  0.073333
# 50%   0.026667  0.026667  0.046667  0.106667  0.180000  0.326667  0.440000
# 100%  0.020000  0.080000  0.193333  0.366667  0.433333  0.500000  0.653333
#
#          10000
# 10%   0.113333
# 50%   0.673333
# 100%  0.666667

# %% [markdown]
# **- Zoom**
# **- Rotation**
# **- All**

# %%
list_dict_results = []
for shift_str in list_shift_str[10:13]:
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[10:13]:
    display(Markdown(f"# {shift}"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Zoom
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.020000  0.026667  0.020000  0.073333  0.120000  0.353333  0.520000
# Medium  0.006667  0.020000  0.046667  0.066667  0.173333  0.446667  0.566667
# Large   0.000000  0.033333  0.033333  0.146667  0.266667  0.460000  0.633333
#
#            10000
# Small   0.666667
# Medium  0.673333
# Large   0.680000
# *Shift proportion vs. # of samples*
#          10        20     50        100       200       500    1000   10000
# 10%   0.013333  0.006667   0.02  0.020000  0.013333  0.026667   0.02   0.02
# 50%   0.006667  0.033333   0.00  0.053333  0.120000  0.306667   0.70   1.00
# 100%  0.006667  0.040000   0.08  0.213333  0.426667  0.926667   1.00   1.00
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.053333  0.040000  0.046667  0.026667  0.053333  0.026667
# Medium  0.013333  0.040000  0.066667  0.046667  0.033333  0.026667  0.026667
# Large   0.006667  0.040000  0.013333  0.033333  0.026667  0.046667  0.093333
#
#            10000
# Small   0.086667
# Medium  0.000000
# Large   0.346667
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.006667  0.033333  0.040000  0.066667  0.020000  0.040000  0.040000
# 50%   0.013333  0.053333  0.053333  0.040000  0.040000  0.040000  0.020000
# 100%  0.006667  0.046667  0.026667  0.020000  0.026667  0.046667  0.086667
#
#          10000
# 10%   0.000000
# 50%   0.040000
# 100%  0.393333
# # Rotation
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.020000  0.026667  0.020000  0.073333  0.120000  0.353333  0.520000
# Medium  0.006667  0.020000  0.046667  0.066667  0.173333  0.446667  0.566667
# Large   0.000000  0.033333  0.033333  0.146667  0.266667  0.460000  0.633333
#
#            10000
# Small   0.666667
# Medium  0.673333
# Large   0.680000
# *Shift proportion vs. # of samples*
#          10        20     50        100       200       500    1000   10000
# 10%   0.013333  0.006667   0.02  0.020000  0.013333  0.026667   0.02   0.02
# 50%   0.006667  0.033333   0.00  0.053333  0.120000  0.306667   0.70   1.00
# 100%  0.006667  0.040000   0.08  0.213333  0.426667  0.926667   1.00   1.00
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.053333  0.040000  0.046667  0.026667  0.053333  0.026667
# Medium  0.013333  0.040000  0.066667  0.046667  0.033333  0.026667  0.026667
# Large   0.006667  0.040000  0.013333  0.033333  0.026667  0.046667  0.093333
#
#            10000
# Small   0.086667
# Medium  0.000000
# Large   0.346667
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.006667  0.033333  0.040000  0.066667  0.020000  0.040000  0.040000
# 50%   0.013333  0.053333  0.053333  0.040000  0.040000  0.040000  0.020000
# 100%  0.006667  0.046667  0.026667  0.020000  0.026667  0.046667  0.086667
#
#          10000
# 10%   0.000000
# 50%   0.040000
# 100%  0.393333
# # All
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.020000  0.026667  0.020000  0.073333  0.120000  0.353333  0.520000
# Medium  0.006667  0.020000  0.046667  0.066667  0.173333  0.446667  0.566667
# Large   0.000000  0.033333  0.033333  0.146667  0.266667  0.460000  0.633333
#
#            10000
# Small   0.666667
# Medium  0.673333
# Large   0.680000
# *Shift proportion vs. # of samples*
#          10        20     50        100       200       500    1000   10000
# 10%   0.013333  0.006667   0.02  0.020000  0.013333  0.026667   0.02   0.02
# 50%   0.006667  0.033333   0.00  0.053333  0.120000  0.306667   0.70   1.00
# 100%  0.006667  0.040000   0.08  0.213333  0.426667  0.926667   1.00   1.00
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.053333  0.040000  0.046667  0.026667  0.053333  0.026667
# Medium  0.013333  0.040000  0.066667  0.046667  0.033333  0.026667  0.026667
# Large   0.006667  0.040000  0.013333  0.033333  0.026667  0.046667  0.093333
#
#            10000
# Small   0.086667
# Medium  0.000000
# Large   0.346667
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.006667  0.033333  0.040000  0.066667  0.020000  0.040000  0.040000
# 50%   0.013333  0.053333  0.053333  0.040000  0.040000  0.040000  0.020000
# 100%  0.006667  0.046667  0.026667  0.020000  0.026667  0.046667  0.086667
#
#          10000
# 10%   0.000000
# 50%   0.040000
# 100%  0.393333

# %% [markdown]
# ### Gaussian shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = [ "BBSDs", "BBSDh"]
list_is_concepts = [False, False]

# %%
list_dict_results = []
for shift_str in list_shift_str[13:14]:
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[13:14]:
    display(Markdown(f"# {shift}"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.013333  0.006667  0.046667  0.006667  0.046667  0.006667  0.026667
# Medium  0.013333  0.013333  0.026667  0.020000  0.033333  0.020000  0.026667
# Large   0.046667  0.173333  0.420000  0.586667  0.666667  0.726667  0.720000
#
#            10000
# Small   0.000000
# Medium  0.346667
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.020000  0.013333  0.033333  0.033333  0.040000  0.066667  0.066667
# 50%   0.013333  0.026667  0.100000  0.233333  0.346667  0.340000  0.346667
# 100%  0.040000  0.153333  0.360000  0.346667  0.360000  0.346667  0.360000
#
#          10000
# 10%   0.333333
# 50%   0.360000
# 100%  0.653333
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.026667  0.040000  0.013333  0.033333  0.066667  0.053333  0.033333
# Medium  0.033333  0.040000  0.020000  0.053333  0.066667  0.060000  0.040000
# Large   0.040000  0.106667  0.166667  0.300000  0.426667  0.600000  0.633333
#
#            10000
# Small   0.000000
# Medium  0.000000
# Large   0.733333
# *Shift proportion vs. # of samples*
#          10        20        50        100    200       500       1000   \
# 10%   0.013333  0.033333  0.026667  0.040000   0.04  0.060000  0.080000
# 50%   0.040000  0.060000  0.053333  0.086667   0.18  0.266667  0.280000
# 100%  0.046667  0.093333  0.120000  0.260000   0.34  0.386667  0.346667
#
#          10000
# 10%   0.066667
# 50%   0.333333
# 100%  0.333333

# %% [markdown]
# ## Detection accuracy vs test samples
#
# The figures plot how detection accuracy changes over different test (real-world) samples provided to each shift detector method. We compare performances of various methods.

# %%
list_shifts = ["Knockout", "Concept (Scale)", "Concept (Shape + Scale)",
              "Concept (X)", "Concept (Y)", "Concept (X + Y)", "Concept (X + Y + Scale)",
              "Translation (X)", "Translation (Y)", "Shear", "Zoom", "Rotation", "All", "Gaussian"]
list_labels = ["CBSDs", "CBSDh", "UAE", "TAE", 
              "BBSDs", "BBSDh", "PCA", "SRP"]
list_is_concepts = [True, True, False, False,
                   False, False, False, False]
list_shift_str = ["ko_task3", "scale_task3", "scale_shape_task3", "x_task3", "y_task3", 
                  "x_y_task3", "x_y_scale_task3", "img_x_task3", "img_y_task3",
                 "shear_task3", "zoom_task3", "rotation_task3", "all_task3", "gaussian_task3"]

# %% [markdown]
# ### Knockout shift

# %%
list_dict_results = []
for shift_str in list_shift_str[:1]:
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[:1]:
    display(Markdown(f"# {shift}"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout

# %% [markdown]
# ### Concept shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "scale", "scale_shape", "x", "y", "x_y", "x_y_scale", "img_x", "img_y",
                 "shear", "zoom", "rotation", "all", "gaussian"]

# %% [markdown]
# **- Scale**
# **- Shape + Scale**
# **- X**

# %%
list_dict_results = []
for shift_str1, shift_str2 in zip(list_shift_str_1[1:4], list_shift_str_2[1:4]):
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False))
        except:
            list_dict_results.append(load_result(shift_str1, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[1:4]:
    display(Markdown(f"# {shift}"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Scale)
# # Concept (Shape + Scale)
# # Concept (X)

# %% [markdown]
# **- Y**
# **- X + Y**
# **- X + Y + Scale**

# %%
list_dict_results = []
for shift_str1, shift_str2 in zip(list_shift_str_1[4:7], list_shift_str_2[4:7]):
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False))
        except:
            list_dict_results.append(load_result(shift_str1, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[4:7]:
    display(Markdown(f"# {shift}"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Y)
# # Concept (X + Y)
# # Concept (X + Y + Scale)

# %% [markdown]
# ### Image shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "scale", "scale_shape", "x", "y", "x_y", "x_y_scale", "img_x", "img_y",
                 "shear", "zoom", "rotation", "all", "gaussian"]

# %% [markdown]
# **- Translation (X)**
# **- Translation (Y)**
# **- Shear**

# %%
list_dict_results = []
for shift_str1, shift_str2 in zip(list_shift_str_1[7:10], list_shift_str_2[7:10]):
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False))
        except:
            list_dict_results.append(load_result(shift_str1, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[7:10]:
    display(Markdown(f"# {shift}"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# # Translation (Y)
# # Shear

# %% [markdown]
# **- Zoom**
# **- Rotation**
# **- All**

# %%
list_dict_results = []
for shift_str1, shift_str2 in zip(list_shift_str_1[10:13], list_shift_str_2[10:13]):
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False))
        except:
            list_dict_results.append(load_result(shift_str1, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[10:13]:
    display(Markdown(f"# {shift}"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Zoom
# # Rotation
# # All

# %% [markdown]
# ### Gaussian shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "scale", "scale_shape", "x", "y", "x_y", "x_y_scale", "img_x", "img_y",
                 "shear", "zoom", "rotation", "all", "gaussian"]

# %%
list_dict_results = []
for shift_str1, shift_str2 in zip(list_shift_str_1[13:14], list_shift_str_2[13:14]):
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False))
        except:
            list_dict_results.append(load_result(shift_str1, label, False))
# Out:
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.
# Loading file successfully.

# %%
for shift in list_shifts[13:14]:
    display(Markdown(f"# {shift}"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian

# %% [markdown]
# ## Barplot explanations
#
# The barplots depict the degree how each concept is affected by various type of shifts. Higher value indicates that the concept is more shifted relative to others.

# %%
list_shifts = ["Knockout"]
list_labels = ["CBSDs", "CBSDh"]
list_shift_str = ["ko_task3"]
list_dict_results = []
for shift_str in list_shift_str:
    temp = []
    for label in list_labels:
        temp.append(load_result(shift_str, label, False))
    list_dict_results.append(temp)

list_shift_intensity = [ShiftIntensity.Large]
list_shift_prop = [1.0]
list_test_sample = [1000, 10000]
concept_names = ["color", "shape", "scale", "rotation", "x", "y"]
# Out:
# Loading file successfully.
# Loading file successfully.

# %%
for shift, dict_result in zip(list_shifts, list_dict_results):
    display(Markdown(f"# {shift}"))
    
    dict_cbsds = dict_result[0]
    dict_cbsdh = dict_result[1]
    
    barplot_test_statistics(dict_cbsds, dict_cbsdh,
                           concept_names, list_shift_intensity,
                           list_shift_prop, list_test_sample)
# Out:
# # Knockout
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 1000
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 10000
