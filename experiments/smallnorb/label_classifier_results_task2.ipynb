# %% [markdown]
# # Label classifier (smallNORB): results
#
# ## Task 2
#
# **Author**: Maleakhi A. Wijaya
# **Description**: This notebook contains code used to visualise experimentation results for the smallNORB dataset. In this file, we focus on task 2: end task to predict the combination of category and lighting of the toy.

# %%
# Load utilities functions
# %run ../../scripts/constants.py
# %run ../../scripts/smallnorb_utils.py
# %run ../../scripts/shift_applicator.py
# %run ../../scripts/shift_dimensionality_reductor.py
# %run ../../scripts/experiment_utils.py
# %run ../../scripts/shift_statistical_test.py

# %% [markdown]
# ## Tables
#
# The tables depict detection accuracy for different sample number against varying shift intensities and shift proportions.

# %%
list_shifts = ["Knockout", "Concept (Instance)", "Concept (Elevation)",
              "Concept (Azimuth)", "Concept (Category + Lighting)",
              "Translation (X)", "Translation (Y)", "Flip", "All", "Gaussian", "FGSM"]
list_labels = ["CBSDh", "BBSDh", "PCA", "SRP"]
list_is_concepts = [True, False, False, False]
list_shift_str = ["ko_task2", "instance_task2", "elevation_task2", "azimuth_task2", "category_lighting_task2",
                  "img_x_task2", "img_y_task2", "flip_task2", "all_task2", "gaussian_task2", "adversarial_task2"]

# %% [markdown]
# ### Knockout shift

# %%
for shift, shift_str in zip(list_shifts[:1], list_shift_str[:1]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.113333  0.220000  0.193333  0.200000  0.153333  0.226667  0.266667
# Medium  0.126667  0.213333  0.166667  0.180000  0.186667  0.220000  0.300000
# Large   0.186667  0.133333  0.186667  0.186667  0.300000  0.386667  0.593333
#
#            10000
# Small   0.973333
# Medium  0.973333
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.133333  0.206667  0.173333  0.226667  0.213333  0.293333  0.286667
# 50%   0.140000  0.193333  0.166667  0.153333  0.186667  0.253333  0.426667
# 100%  0.153333  0.166667  0.206667  0.186667  0.240000  0.286667  0.446667
#
#          10000
# 10%   0.973333
# 50%   0.986667
# 100%  0.986667
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#         10        20        50        100       200       500    1000   10000
# Small     0.0  0.026667  0.013333  0.020000  0.013333  0.033333   0.02    0.0
# Medium    0.0  0.000000  0.000000  0.006667  0.013333  0.006667   0.00    1.0
# Large     0.0  0.020000  0.033333  0.033333  0.040000  0.453333   0.96    1.0
# *Shift proportion vs. # of samples*
#       10        20        50        100       200       500       1000   \
# 10%     0.0  0.020000  0.013333  0.020000  0.026667  0.140000  0.333333
# 50%     0.0  0.006667  0.013333  0.013333  0.026667  0.200000  0.326667
# 100%    0.0  0.020000  0.020000  0.026667  0.013333  0.153333  0.320000
#
#          10000
# 10%   0.666667
# 50%   0.666667
# 100%  0.666667
# ## Method: PCA
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500    1000   \
# Small   0.033333  0.066667  0.046667  0.040000  0.040000  0.100000    0.0
# Medium  0.006667  0.013333  0.040000  0.060000  0.026667  0.066667    0.0
# Large   0.060000  0.026667  0.053333  0.046667  0.080000  0.086667    0.0
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#       10        20        50        100       200       500    1000   10000
# 10%    0.02  0.026667  0.053333  0.060000  0.060000  0.066667    0.0    0.0
# 50%    0.04  0.040000  0.046667  0.033333  0.040000  0.093333    0.0    0.0
# 100%   0.04  0.040000  0.040000  0.053333  0.046667  0.093333    0.0    0.0
# ## Method: SRP
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500    1000   \
# Small   0.046667  0.033333  0.053333  0.053333  0.086667  0.053333    0.0
# Medium  0.033333  0.060000  0.013333  0.080000  0.073333  0.060000    0.0
# Large   0.053333  0.040000  0.053333  0.060000  0.046667  0.133333    0.0
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500    1000   10000
# 10%   0.033333  0.046667  0.033333  0.053333  0.073333  0.080000    0.0    0.0
# 50%   0.046667  0.040000  0.040000  0.053333  0.120000  0.080000    0.0    0.0
# 100%  0.053333  0.046667  0.046667  0.086667  0.013333  0.086667    0.0    0.0

# %% [markdown]
# ### Concept shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = ["BBSDh"]
list_is_concepts = [False]

# %% [markdown]
# - Instance
# - Elevation
# - Azimuth
# - Category and lighting

# %%
for shift, shift_str in zip(list_shifts[1:5], list_shift_str[1:5]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Instance)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10     20        50        100       200       500       1000   \
# Small   0.080000   0.04  0.040000  0.033333  0.040000  0.033333  0.020000
# Medium  0.020000   0.06  0.066667  0.086667  0.026667  0.053333  0.013333
# Large   0.046667   0.06  0.000000  0.053333  0.040000  0.040000  0.020000
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.046667  0.046667  0.040000  0.053333  0.040000  0.046667  0.006667
# 50%   0.046667  0.073333  0.006667  0.046667  0.020000  0.053333  0.020000
# 100%  0.053333  0.040000  0.060000  0.073333  0.046667  0.026667  0.026667
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# # Concept (Elevation)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.060000  0.026667  0.046667  0.073333  0.026667  0.026667  0.033333
# Medium  0.066667  0.073333  0.040000  0.033333  0.026667  0.040000  0.026667
# Large   0.073333  0.073333  0.033333  0.040000  0.040000  0.033333  0.053333
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.080000  0.073333  0.066667  0.060000  0.033333  0.053333  0.066667
# 50%   0.053333  0.053333  0.046667  0.026667  0.033333  0.020000  0.013333
# 100%  0.066667  0.046667  0.006667  0.060000  0.026667  0.026667  0.033333
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# # Concept (Azimuth)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.040000  0.053333  0.086667  0.060000  0.033333  0.033333  0.033333
# Medium  0.053333  0.066667  0.046667  0.046667  0.046667  0.026667  0.026667
# Large   0.060000  0.033333  0.086667  0.040000  0.060000  0.060000  0.033333
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.060000  0.086667  0.093333  0.040000  0.060000  0.040000  0.026667
# 50%   0.066667  0.020000  0.040000  0.053333  0.033333  0.046667  0.053333
# 100%  0.026667  0.046667  0.086667  0.053333  0.046667  0.033333  0.013333
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# # Concept (Category + Lighting)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500    1000   \
# Small   0.026667  0.020000  0.026667  0.053333  0.046667  0.020000   0.02
# Medium  0.006667  0.026667  0.000000  0.066667  0.086667  0.746667   1.00
# Large   0.040000  0.093333  0.220000  0.906667  1.000000  1.000000   1.00
#
#            10000
# Small   0.006667
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.013333  0.053333  0.086667  0.340000  0.413333  0.600000  0.666667
# 50%   0.020000  0.046667  0.086667  0.326667  0.340000  0.586667  0.666667
# 100%  0.040000  0.040000  0.073333  0.360000  0.380000  0.580000  0.686667
#
#          10000
# 10%   0.673333
# 50%   0.666667
# 100%  0.666667

# %% [markdown]
# ### Image shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = ["BBSDh"]
list_is_concepts = [False]

# %% [markdown]
# - Translation (X)
# - Translation (Y)
# - Flip
# - All

# %%
for shift, shift_str in zip(list_shifts[5:9], list_shift_str[5:9]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.046667  0.053333  0.020000  0.053333  0.026667  0.060000  0.073333
# Medium  0.093333  0.080000  0.146667  0.326667  0.460000  0.633333  0.700000
# Large   0.120000  0.126667  0.333333  0.553333  0.633333  0.686667  0.706667
#
#            10000
# Small   0.313333
# Medium  0.673333
# Large   0.946667
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.040000  0.066667  0.026667  0.053333  0.040000  0.053333  0.073333
# 50%   0.113333  0.040000  0.113333  0.266667  0.406667  0.633333  0.700000
# 100%  0.106667  0.153333  0.360000  0.613333  0.673333  0.693333  0.706667
#
#          10000
# 10%   0.286667
# 50%   0.666667
# 100%  0.980000
# # Translation (Y)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.066667  0.033333  0.073333  0.033333  0.026667  0.046667  0.040000
# Medium  0.066667  0.060000  0.146667  0.173333  0.346667  0.520000  0.613333
# Large   0.073333  0.120000  0.360000  0.506667  0.653333  0.720000  0.740000
#
#            10000
# Small   0.013333
# Medium  0.666667
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.066667  0.040000  0.073333  0.020000  0.066667  0.093333  0.093333
# 50%   0.040000  0.033333  0.140000  0.226667  0.333333  0.506667  0.620000
# 100%  0.100000  0.140000  0.366667  0.466667  0.626667  0.686667  0.680000
#
#          10000
# 10%   0.333333
# 50%   0.666667
# 100%  0.680000
# # Flip
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.053333  0.053333  0.046667  0.040000  0.040000  0.020000  0.040000
# Medium  0.093333  0.066667  0.066667  0.100000  0.180000  0.373333  0.473333
# Large   0.106667  0.186667  0.313333  0.453333  0.626667  0.686667  0.693333
#
#            10000
# Small   0.000000
# Medium  0.666667
# Large   0.793333
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.073333  0.053333  0.033333  0.046667  0.060000  0.040000  0.066667
# 50%   0.066667  0.073333  0.120000  0.140000  0.320000  0.433333  0.460000
# 100%  0.113333  0.180000  0.273333  0.406667  0.466667  0.606667  0.680000
#
#          10000
# 10%   0.126667
# 50%   0.666667
# 100%  0.666667
# # All
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200    500       1000   \
# Small   0.046667  0.046667  0.066667  0.080000  0.080000   0.10  0.240000
# Medium  0.100000  0.120000  0.220000  0.433333  0.553333   0.66  0.693333
# Large   0.286667  0.286667  0.546667  0.653333  0.726667   0.74  0.800000
#
#            10000
# Small   0.566667
# Medium  0.853333
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.073333  0.053333  0.046667  0.066667  0.100000  0.100000  0.166667
# 50%   0.113333  0.106667  0.273333  0.440000  0.553333  0.666667  0.700000
# 100%  0.246667  0.293333  0.513333  0.660000  0.706667  0.733333  0.866667
#
#       10000
# 10%    0.52
# 50%    0.90
# 100%   1.00

# %% [markdown]
# ### Gaussian shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = ["BBSDh"]
list_is_concepts = [False]

# %%
for shift, shift_str in zip(list_shifts[9:10], list_shift_str[9:10]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.026667  0.040000  0.026667  0.053333  0.046667  0.046667  0.026667
# Medium  0.033333  0.066667  0.040000  0.060000  0.080000  0.066667  0.026667
# Large   0.673333  0.700000  0.720000  0.866667  0.966667  1.000000  1.000000
#
#         10000
# Small     0.0
# Medium    0.0
# Large     1.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.066667  0.086667  0.073333  0.233333  0.326667  0.393333  0.353333
# 50%   0.326667  0.353333  0.353333  0.366667  0.386667  0.366667  0.333333
# 100%  0.340000  0.366667  0.360000  0.380000  0.380000  0.353333  0.366667
#
#          10000
# 10%   0.333333
# 50%   0.333333
# 100%  0.333333

# %% [markdown]
# ## Detection accuracy vs test samples
#
# The figures plot how detection accuracy changes over different test (real-world) samples provided to each shift detector method. We compare performances of various methods.

# %%
list_shifts = ["Knockout", "Concept (Instance)", "Concept (Elevation)",
              "Concept (Azimuth)", "Concept (Category + Lighting)",
              "Translation (X)", "Translation (Y)", "Flip", "All", "Gaussian", "FGSM"]
list_labels = ["CBSDh", "BBSDh", "PCA", "SRP"]
list_is_concepts = [True, False, False, False]
list_shift_str = ["ko_task2", "instance_task2", "elevation_task2", "azimuth_task2", "category_lighting_task2",
                  "img_x_task2", "img_y_task2", "flip_task2", "all_task2", "gaussian_task2", "adversarial_task2"]

# %% [markdown]
# ### Knockout shift

# %%
for shift, shift_str in zip(list_shifts[:1], list_shift_str[:1]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout

# %% [markdown]
# ### Concept shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "instance", "elevation", "azimuth", "category_lighting",
                  "img_x", "img_y", "flip", "all", "gaussian", "adversarial"]

# %% [markdown]
# - Instance
# - Elevation
# - Azimuth
# - Category and lighting

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[1:5], list_shift_str_1[1:5], list_shift_str_2[1:5]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False, "smallnorb"))
        except:
            list_dict_results.append(load_result(shift_str1, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Instance)
# # Concept (Elevation)
# # Concept (Azimuth)
# # Concept (Category + Lighting)

# %% [markdown]
# ### Image shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "instance", "elevation", "azimuth", "category_lighting",
                  "img_x", "img_y", "flip", "all", "gaussian", "adversarial"]

# %% [markdown]
# - Translation (X)
# - Translation (Y)
# - Flip
# - All

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[5:9], list_shift_str_1[5:9], list_shift_str_2[5:9]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False, "smallnorb"))
        except:
            list_dict_results.append(load_result(shift_str1, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# # Translation (Y)
# # Flip
# # All

# %% [markdown]
# ### Gaussian shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "instance", "elevation", "azimuth", "category_lighting",
                  "img_x", "img_y", "flip", "all", "gaussian", "adversarial"]

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[9:10], list_shift_str_1[9:10], list_shift_str_2[9:10]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False, "smallnorb"))
        except:
            list_dict_results.append(load_result(shift_str1, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian

# %% [markdown]
# ## Barplot explanations
#
# The barplots depict the degree how each concept is affected by various type of shifts. Higher value indicates that the concept is more shifted relative to others.

# %%
# list_shifts = ["Knockout"]
# list_labels = ["CBSDs", "CBSDh"]
# list_shift_str = ["ko_task2"]
# list_dict_results = []
# for shift_str in list_shift_str:
#     temp = []
#     for label in list_labels:
#         temp.append(load_result(shift_str, label, False))
#     list_dict_results.append(temp)

# list_shift_intensity = [ShiftIntensity.Large]
# list_shift_prop = [1.0]
# list_test_sample = [1000, 10000]
# concept_names = ['category', 'instance', 'elevation', 'azimuth', 'lighting']

# %%
# for shift, dict_result in zip(list_shifts, list_dict_results):
#     display(Markdown(f"# {shift}"))
    
#     dict_cbsds = dict_result[0]
#     dict_cbsdh = dict_result[1]
    
#     barplot_test_statistics(dict_cbsds, dict_cbsdh,
#                            concept_names, list_shift_intensity,
#                            list_shift_prop, list_test_sample)
