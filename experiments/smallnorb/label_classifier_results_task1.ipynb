# %% [markdown]
# # Label classifier (smallNORB): results
#
# ## Task 1
#
# **Author**: Maleakhi A. Wijaya
# **Description**: This notebook contains code used to visualise experimentation results for the smallnorb dataset. In this file, we focus on task 1: end task to predict category of the toy images.

# %%
# Load utilities functions
# %run ../../scripts/constants.py
# %run ../../scripts/smallnorb_utils.py
# %run ../../scripts/shift_applicator.py
# %run ../../scripts/shift_dimensionality_reductor.py
# %run ../../scripts/experiment_utils.py
# %run ../../scripts/shift_statistical_test.py

# %% [markdown]
# ## Tables
#
# The tables depict detection accuracy for different sample number against varying shift intensities and shift proportions.

# %%
list_shifts = ["Knockout", "Concept (Instance)", "Concept (Elevation)",
              "Concept (Azimuth)", "Concept (Category + Lighting)",
              "Translation (X)", "Translation (Y)", "Flip", "All", "Gaussian", "FGSM"]
list_labels = ["CBSDh", "CBSDs", "BBSDh", "BBSDs", "PCA", "SRP"]
list_is_concepts = [True, True, False, False, False, False]
list_shift_str = ["ko", "instance", "elevation", "azimuth", "category_lighting",
                  "img_x", "img_y", "flip", "all", "gaussian", "adversarial"]

# %% [markdown]
# ### Knockout shift

# %%
for shift, shift_str in zip(list_shifts[:1], list_shift_str[:1]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200    500       1000   \
# Small   0.126667  0.213333  0.220000  0.200000  0.246667   0.18  0.193333
# Medium  0.173333  0.200000  0.233333  0.173333  0.246667   1.00  1.000000
# Large   0.200000  0.186667  0.933333  1.000000  1.000000   1.00  1.000000
#
#            10000
# Small   0.926667
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.193333  0.186667  0.460000  0.480000  0.486667  0.733333  0.746667
# 50%   0.133333  0.166667  0.413333  0.466667  0.533333  0.726667  0.740000
# 100%  0.173333  0.246667  0.513333  0.426667  0.473333  0.720000  0.706667
#
#          10000
# 10%   0.980000
# 50%   0.966667
# 100%  0.980000
# ## Method: CBSDs
# *Shift intensities vs. # of samples*
# ...

# %% [markdown]
# ### Concept shift

# %% [markdown]
# - Instance
# - Elevation
# - Azimuth
# - Category and lighting

# %%
for shift, shift_str in zip(list_shifts[1:5], list_shift_str[1:5]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Instance)
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.133333  0.233333  0.186667  0.206667  0.260000  0.193333  0.173333
# Medium  0.173333  0.200000  0.193333  0.246667  0.186667  0.353333  0.706667
# Large   0.166667  0.180000  0.260000  0.420000  0.926667  1.000000  1.000000
#
#            10000
# Small   0.906667
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.173333  0.186667  0.180000  0.300000  0.473333  0.526667  0.646667
# 50%   0.140000  0.233333  0.193333  0.313333  0.473333  0.513333  0.593333
# 100%  0.160000  0.193333  0.266667  0.260000  0.426667  0.506667  0.640000
#
#          10000
# 10%   0.980000
# 50%   0.960000
# 100%  0.966667
# ## Method: CBSDs
# *Shift intensities vs. # of samples*
# ...

# %% [markdown]
# ### Image shift
#
# - Translation (X)
# - Translation (Y)
# - Flip
# - All

# %%
for shift, shift_str in zip(list_shifts[5:9], list_shift_str[5:9]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.213333  0.233333  0.286667  0.253333  0.393333  0.493333  0.600000
# Medium  0.253333  0.313333  0.333333  0.520000  0.673333  0.753333  0.793333
# Large   0.280000  0.473333  0.580000  0.753333  0.740000  0.833333  0.893333
#
#            10000
# Small   0.993333
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.200000  0.253333  0.186667  0.286667  0.293333  0.380000  0.453333
# 50%   0.260000  0.260000  0.393333  0.513333  0.660000  0.773333  0.846667
# 100%  0.286667  0.506667  0.620000  0.726667  0.853333  0.926667  0.986667
#
#          10000
# 10%   0.993333
# 50%   1.000000
# 100%  1.000000
# ## Method: CBSDs
# *Shift intensities vs. # of samples*
# ...

# %% [markdown]
# ### Gaussian shift

# %%
for shift, shift_str in zip(list_shifts[9:10], list_shift_str[9:10]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.240000  0.193333  0.206667  0.200000  0.220000  0.246667  0.286667
# Medium  0.213333  0.146667  0.233333  0.213333  0.306667  0.480000  0.606667
# Large   0.620000  0.780000  0.780000  0.826667  0.940000  0.993333  1.000000
#
#            10000
# Small   0.926667
# Medium  0.986667
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10     20        50     100       200       500       1000      10000
# 10%   0.200000   0.22  0.253333   0.30  0.460000  0.466667  0.560000  0.960000
# 50%   0.406667   0.46  0.493333   0.46  0.460000  0.573333  0.586667  0.973333
# 100%  0.466667   0.44  0.473333   0.48  0.546667  0.680000  0.746667  0.980000
# ## Method: CBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# ...

# %% [markdown]
# ### Adversarial shift

# %%
for shift, shift_str in zip(list_shifts[10:11], list_shift_str[10:11]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # FGSM
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.206667  0.280000  0.280000  0.366667  0.473333  0.746667  0.986667
# Medium  0.466667  0.726667  0.986667  1.000000  1.000000  1.000000  1.000000
# Large   0.953333  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
#         10000
# Small     1.0
# Medium    1.0
# Large     1.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.546667  0.686667  0.753333  0.826667  0.853333  0.900000  0.993333
# 50%   0.560000  0.633333  0.733333  0.786667  0.800000  0.926667  1.000000
# 100%  0.520000  0.686667  0.780000  0.753333  0.820000  0.920000  0.993333
#
#       10000
# 10%     1.0
# 50%     1.0
# 100%    1.0
# ## Method: CBSDs
# *Shift intensities vs. # of samples*
#            10        20     50        100       200       500    1000   10000
# ...

# %% [markdown]
# ## Detection accuracy vs test samples
#
# The figures plot how detection accuracy changes over different test (real-world) samples provided to each shift detector method. We compare performances of various methods.

# %%
list_shifts = ["Knockout", "Concept (Instance)", "Concept (Elevation)",
              "Concept (Azimuth)", "Concept (Category + Lighting)",
              "Translation (X)", "Translation (Y)", "Flip", "All", "Gaussian", "FGSM"]
list_labels = ["CBSDs", "CBSDh", "PCA", "SRP", "BBSDs", "BBSDh"]
list_is_concepts = [True, True, False, False, False, False]
list_shift_str = ["ko", "instance", "elevation", "azimuth", "category_lighting",
                  "img_x", "img_y", "flip", "all", "gaussian", "adversarial"]

# %% [markdown]
# ### Knockout shift

# %%
for shift, shift_str in zip(list_shifts[:1], list_shift_str[:1]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout

# %% [markdown]
# ### Concept shift

# %% [markdown]
# - Instance
# - Elevation
# - Azimuth
# - Category and lighting

# %%
for shift, shift_str in zip(list_shifts[1:5], list_shift_str[1:5]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Instance)
# # Concept (Elevation)
# # Concept (Azimuth)
# # Concept (Category + Lighting)

# %% [markdown]
# ### Image shift
#
# - Translation (X)
# - Translation (Y)
# - Flip
# - All

# %%
for shift, shift_str in zip(list_shifts[5:9], list_shift_str[5:9]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# # Translation (Y)
# # Flip
# # All

# %% [markdown]
# ### Gaussian shift

# %%
for shift, shift_str in zip(list_shifts[9:10], list_shift_str[9:10]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian

# %% [markdown]
# ### Adversarial shift

# %%
for shift, shift_str in zip(list_shifts[10:11], list_shift_str[10:11]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # FGSM

# %% [markdown]
# ## Barplot explanations
#
# The barplots depict the degree how each concept is affected by various type of shifts. Higher value indicates that the concept is more shifted relative to others.

# %%
list_shifts = ["Knockout", "Concept (Instance)", "Concept (Elevation)",
              "Concept (Azimuth)", "Concept (Category + Lighting)",
              "Translation (X)", "Translation (Y)", "Flip", "All", "Gaussian", "FGSM"]
list_labels = ["CBSDs", "CBSDh"]
list_shift_str = ["ko", "instance", "elevation", "azimuth", "category_lighting",
                  "img_x", "img_y", "flip", "all", "gaussian", "adversarial"]
list_dict_results = []
for shift_str in list_shift_str:
    temp = []
    for label in list_labels:
        temp.append(load_result(shift_str, label, False, "smallnorb"))
    list_dict_results.append(temp)

list_shift_intensity = [ShiftIntensity.Large]
list_shift_prop = [1.0]
list_test_sample = [1000, 10000]
concept_names = ['category', 'instance', 'elevation', 'azimuth', 'lighting']

# %%
for shift, dict_result in zip(list_shifts, list_dict_results):
    display(Markdown(f"# {shift}"))
    
    dict_cbsds = dict_result[0]
    dict_cbsdh = dict_result[1]
        
    barplot_test_statistics(dict_cbsds, dict_cbsdh,
                           concept_names, list_shift_intensity,
                           list_shift_prop, list_test_sample)
# Out:
# # Knockout
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 1000
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 10000
# # Concept (Instance)
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 1000
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 10000
# # Concept (Elevation)
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 1000
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 10000
# # Concept (Azimuth)
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 1000
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 10000
# # Concept (Category + Lighting)
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 1000
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 10000
# # Translation (X)
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 1000
# Shift intensity: Large
# Shift proportion: 1.0
# ...

# %% [markdown]
# ### Parallel coordinate plot of p-values
#
# The parallel coordinate plot shows average p-values over different shift types (axis, methods (axis), shift intensity (axis), shift proportion (axis), and number of test samples (axis).

# %%
# list_shift_types = [ShiftType.Knockout, ShiftType.Concept]
# list_shift_str = ["ko", "scale"]
# list_methods = ["CBSDs", "CBSDh", "UAE", "TAE", 
#               "BBSDs", "BBSDh", "PCA", "SRP"]
# list_is_concepts = [True, True, False, False,
#                    False, False, False, False]
# list_dict_results = []
# for shift in list_shift_str:
#     for method in list_methods:
#         list_dict_results.append(load_result(shift, method, False))

# %%
# parallel_coordinate_p_values(list_shift_types, list_shift_str,
#                             list_dict_results, list_methods,
#                             list_is_concepts)
