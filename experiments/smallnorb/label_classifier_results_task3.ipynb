# %% [markdown]
# # Label classifier (smallNORB): results
#
# ## Task 3
#
# **Author**: Maleakhi A. Wijaya
# **Description**: This notebook contains code used to visualise experimentation results for the smallNORB dataset. In this file, we focus on task 3: end task to predict the binary clusters of concept 'azimuth'.

# %%
# Load utilities functions
# %run ../../scripts/constants.py
# %run ../../scripts/smallnorb_utils.py
# %run ../../scripts/shift_applicator.py
# %run ../../scripts/shift_dimensionality_reductor.py
# %run ../../scripts/experiment_utils.py
# %run ../../scripts/shift_statistical_test.py

# %% [markdown]
# ## Tables
#
# The tables depict detection accuracy for different sample number against varying shift intensities and shift proportions.

# %%
list_shifts = ["Knockout", "Concept (Instance)", "Concept (Elevation)",
              "Concept (Azimuth)", "Concept (Category + Lighting)",
              "Translation (X)", "Translation (Y)", "Flip", "All", "Gaussian", "FGSM"]
list_labels = ["CBSDh", "BBSDh", "PCA", "SRP"]
list_is_concepts = [True, False, False, False]
list_shift_str = ["ko_task3", "instance_task3", "elevation_task3", "azimuth_task3", "category_lighting_task3",
                  "img_x_task3", "img_y_task3", "flip_task3", "all_task3", "gaussian_task3", "adversarial_task3"]

# %% [markdown]
# ### Knockout shift

# %%
for shift, shift_str in zip(list_shifts[:1], list_shift_str[:1]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.240000  0.266667  0.226667  0.206667  0.220000  0.233333  0.173333
# Medium  0.193333  0.206667  0.140000  0.306667  0.426667  0.880000  1.000000
# Large   0.213333  0.433333  0.760000  0.980000  1.000000  1.000000  1.000000
#
#            10000
# Small   0.153333
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.220000  0.286667  0.360000  0.520000  0.540000  0.680000  0.726667
# 50%   0.226667  0.326667  0.386667  0.493333  0.560000  0.706667  0.733333
# 100%  0.200000  0.293333  0.380000  0.480000  0.546667  0.726667  0.713333
#
#          10000
# 10%   0.733333
# 50%   0.713333
# 100%  0.706667
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200    500    1000   \
# Small   0.013333  0.020000  0.006667  0.006667  0.000000    0.0   0.02
# Medium  0.000000  0.000000  0.080000  0.606667  0.973333    1.0   1.00
# Large   0.646667  0.906667  1.000000  1.000000  1.000000    1.0   1.00
#
#            10000
# Small   0.153333
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.200000  0.313333  0.353333  0.566667  0.646667  0.666667  0.680000
# 50%   0.233333  0.306667  0.360000  0.520000  0.666667  0.666667  0.666667
# 100%  0.226667  0.306667  0.373333  0.526667  0.660000  0.666667  0.673333
#
#          10000
# 10%   0.740000
# 50%   0.713333
# 100%  0.700000
# ## Method: PCA
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.046667  0.073333  0.033333  0.046667  0.060000  0.040000  0.000000
# Medium  0.053333  0.053333  0.066667  0.040000  0.026667  0.080000  0.066667
# Large   0.046667  0.020000  0.066667  0.066667  0.066667  0.126667  0.180000
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.040000  0.053333  0.046667  0.033333  0.046667  0.080000  0.053333
# 50%   0.040000  0.026667  0.053333  0.060000  0.046667  0.086667  0.086667
# 100%  0.066667  0.066667  0.066667  0.060000  0.060000  0.080000  0.106667
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# ## Method: SRP
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.060000  0.060000  0.020000  0.053333  0.040000  0.046667  0.000000
# Medium  0.026667  0.033333  0.040000  0.060000  0.020000  0.026667  0.066667
# Large   0.040000  0.040000  0.086667  0.073333  0.086667  0.106667  0.220000
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.040000  0.026667  0.060000  0.066667  0.066667  0.060000  0.093333
# 50%   0.060000  0.053333  0.060000  0.073333  0.046667  0.073333  0.100000
# 100%  0.026667  0.053333  0.026667  0.046667  0.033333  0.046667  0.093333
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0

# %%
for shift in list_shifts[:1]:
    display(Markdown(f"# {shift}"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout
# ## Method: CBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.030000  0.030000  0.023333  0.046667  0.036667  0.060000  0.076667
# Medium  0.036667  0.023333  0.033333  0.036667  0.046667  0.070000  0.086667
# Large   0.013333  0.036667  0.046667  0.030000  0.156667  0.873333  1.000000
#
#            10000
# Small   0.013333
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.036667  0.030000  0.030000  0.020000  0.093333  0.330000  0.390000
# 50%   0.016667  0.036667  0.033333  0.060000  0.070000  0.333333  0.376667
# 100%  0.026667  0.023333  0.040000  0.033333  0.076667  0.340000  0.396667
#
#          10000
# 10%   0.676667
# 50%   0.666667
# 100%  0.670000
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.243333  0.213333  0.196667  0.233333  0.240000  0.266667  0.266667
# Medium  0.200000  0.220000  0.206667  0.286667  0.383333  0.820000  1.000000
# Large   0.213333  0.270000  0.606667  0.966667  1.000000  1.000000  1.000000
#
#         10000
# Small    0.42
# Medium   1.00
# Large    1.00
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.256667  0.230000  0.310000  0.506667  0.556667  0.686667  0.760000
# 50%   0.226667  0.243333  0.346667  0.453333  0.543333  0.690000  0.760000
# 100%  0.173333  0.230000  0.353333  0.526667  0.523333  0.710000  0.746667
#
#          10000
# 10%   0.803333
# 50%   0.813333
# 100%  0.803333
# ## Method: UAE
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.003333  0.013333  0.000000  0.010000  0.010000  0.000000  0.006667
# Medium  0.000000  0.013333  0.313333  0.190000  0.190000  0.050000  0.106667
# Large   0.000000  0.010000  0.080000  0.276667  0.276667  0.596667  0.950000
#
#            10000
# Small   0.053333
# Medium  0.776667
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.003333  0.013333  0.146667  0.166667  0.166667  0.236667  0.350000
# 50%   0.000000  0.016667  0.143333  0.143333  0.143333  0.210000  0.366667
# 100%  0.000000  0.006667  0.103333  0.166667  0.166667  0.200000  0.346667
#
#          10000
# 10%   0.610000
# 50%   0.633333
# 100%  0.586667
# ## Method: TAE
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.003333  0.003333  0.003333  0.003333  0.150000  0.010000  0.003333
# Medium  0.093333  0.093333  0.093333  0.093333  0.093333  0.053333  0.123333
# Large   0.093333  0.093333  0.370000  0.370000  0.370000  0.660000  0.966667
#
#            10000
# Small   0.016667
# Medium  0.936667
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.073333  0.073333  0.146667  0.146667  0.203333  0.253333  0.366667
# 50%   0.066667  0.066667  0.186667  0.186667  0.230000  0.226667  0.363333
# 100%  0.050000  0.050000  0.133333  0.133333  0.180000  0.243333  0.363333
#
#          10000
# 10%   0.663333
# 50%   0.650000
# 100%  0.640000
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.010000  0.013333  0.000000  0.010000  0.003333  0.006667  0.003333
# Medium  0.006667  0.006667  0.036667  0.276667  0.873333  1.000000  1.000000
# Large   0.066667  0.583333  1.000000  1.000000  1.000000  1.000000  1.000000
#
#            10000
# Small   0.956667
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.016667  0.196667  0.350000  0.426667  0.613333  0.670000  0.666667
# 50%   0.040000  0.210000  0.340000  0.420000  0.630000  0.670000  0.670000
# 100%  0.026667  0.196667  0.346667  0.440000  0.633333  0.666667  0.666667
#
#          10000
# 10%   0.986667
# 50%   0.986667
# 100%  0.983333
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200    500       1000   \
# Small   0.020000  0.020000  0.016667  0.010000  0.003333   0.01  0.003333
# Medium  0.000000  0.003333  0.046667  0.466667  0.946667   1.00  1.000000
# Large   0.523333  0.776667  1.000000  1.000000  1.000000   1.00  1.000000
#
#         10000
# Small     1.0
# Medium    1.0
# Large     1.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.140000  0.273333  0.353333  0.483333  0.650000  0.673333  0.666667
# 50%   0.200000  0.263333  0.350000  0.486667  0.653333  0.670000  0.670000
# 100%  0.203333  0.263333  0.360000  0.506667  0.646667  0.666667  0.666667
#
#       10000
# 10%     1.0
# 50%     1.0
# 100%    1.0
# ## Method: PCA
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.056667  0.050000  0.076667  0.043333  0.066667  0.070000  0.080000
# Medium  0.070000  0.050000  0.046667  0.053333  0.050000  0.080000  0.203333
# Large   0.056667  0.073333  0.073333  0.100000  0.190000  0.543333  0.940000
#
#            10000
# Small   0.156667
# Medium  0.783333
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.053333  0.056667  0.063333  0.083333  0.103333  0.246667  0.390000
# 50%   0.063333  0.066667  0.053333  0.050000  0.100000  0.213333  0.403333
# 100%  0.066667  0.050000  0.080000  0.063333  0.103333  0.233333  0.430000
#
#          10000
# 10%   0.646667
# 50%   0.646667
# 100%  0.646667
# ## Method: SRP
# *Shift intensities vs. # of samples*
#            10     20        50        100       200       500       1000   \
# Small   0.006667   0.00  0.010000  0.003333  0.003333  0.006667  0.013333
# Medium  0.016667   0.01  0.006667  0.003333  0.020000  0.020000  0.060000
# Large   0.023333   0.02  0.020000  0.036667  0.116667  0.543333  0.956667
#
#            10000
# Small   0.003333
# Medium  0.943333
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.010000  0.013333  0.020000  0.013333  0.033333  0.183333  0.333333
# 50%   0.016667  0.003333  0.010000  0.023333  0.056667  0.216667  0.353333
# 100%  0.020000  0.013333  0.006667  0.006667  0.050000  0.170000  0.343333
#
#          10000
# 10%   0.653333
# 50%   0.640000
# 100%  0.653333

# %% [markdown]
# ### Concept shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = ["BBSDh"]
list_is_concepts = [False]

# %% [markdown]
# - Instance
# - Elevation
# - Azimuth
# - Category and lighting

# %%
for shift, shift_str in zip(list_shifts[1:5], list_shift_str[1:5]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Instance)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.040000  0.026667  0.033333  0.053333  0.046667  0.046667  0.093333
# Medium  0.013333  0.006667  0.033333  0.040000  0.033333  0.073333  0.093333
# Large   0.013333  0.013333  0.033333  0.020000  0.053333  0.053333  0.086667
#
#            10000
# Small   0.380000
# Medium  0.346667
# Large   0.286667
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.000000  0.013333  0.040000  0.026667  0.046667  0.060000  0.093333
# 50%   0.013333  0.020000  0.013333  0.060000  0.040000  0.060000  0.120000
# 100%  0.053333  0.013333  0.046667  0.026667  0.046667  0.053333  0.060000
#
#          10000
# 10%   0.340000
# 50%   0.333333
# 100%  0.340000
# # Concept (Elevation)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.053333  0.000000  0.033333  0.040000  0.066667  0.073333  0.120000
# Medium  0.026667  0.000000  0.040000  0.026667  0.020000  0.080000  0.086667
# Large   0.033333  0.033333  0.020000  0.026667  0.080000  0.053333  0.100000
#
#            10000
# Small   0.406667
# Medium  0.393333
# Large   0.366667
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.026667  0.006667  0.026667  0.033333  0.046667  0.073333  0.100000
# 50%   0.033333  0.020000  0.013333  0.026667  0.073333  0.060000  0.100000
# 100%  0.053333  0.006667  0.053333  0.033333  0.046667  0.073333  0.106667
#
#          10000
# 10%   0.386667
# 50%   0.326667
# 100%  0.453333
# # Concept (Azimuth)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.013333  0.013333  0.033333  0.060000  0.026667  0.066667
# Medium  0.013333  0.020000  0.026667  0.006667  0.040000  0.020000  0.093333
# Large   0.013333  0.013333  0.026667  0.073333  0.066667  0.173333  0.320000
#
#            10000
# Small   0.073333
# Medium  0.033333
# Large   0.886667
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.006667  0.026667  0.033333  0.060000  0.046667  0.066667  0.220000
# 50%   0.006667  0.006667  0.013333  0.026667  0.060000  0.086667  0.146667
# 100%  0.020000  0.013333  0.020000  0.026667  0.060000  0.066667  0.113333
#
#          10000
# 10%   0.333333
# 50%   0.320000
# 100%  0.340000
# # Concept (Category + Lighting)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.000000  0.033333  0.053333  0.026667  0.020000  0.093333  0.073333
# Medium  0.033333  0.020000  0.020000  0.033333  0.026667  0.073333  0.040000
# Large   0.086667  0.020000  0.020000  0.020000  0.073333  0.046667  0.100000
#
#            10000
# Small   0.386667
# Medium  0.446667
# Large   0.286667
# *Shift proportion vs. # of samples*
#       10        20        50        100       200       500       1000   \
# 10%    0.06  0.006667  0.033333  0.020000  0.053333  0.066667  0.060000
# 50%    0.04  0.040000  0.033333  0.033333  0.033333  0.040000  0.100000
# 100%   0.02  0.026667  0.026667  0.026667  0.033333  0.106667  0.053333
#
#          10000
# 10%   0.300000
# 50%   0.446667
# 100%  0.373333

# %% [markdown]
# ### Image shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = ["BBSDh"]
list_is_concepts = [False]

# %% [markdown]
# - Translation (X)
# - Translation (Y)
# - Flip
# - All

# %%
for shift, shift_str in zip(list_shifts[5:9], list_shift_str[5:9]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.013333  0.060000  0.040000  0.040000  0.053333  0.053333  0.140000
# Medium  0.046667  0.080000  0.033333  0.093333  0.060000  0.060000  0.126667
# Large   0.020000  0.046667  0.040000  0.073333  0.193333  0.286667  0.413333
#
#            10000
# Small   0.620000
# Medium  0.406667
# Large   0.653333
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.026667  0.053333  0.020000  0.060000  0.033333  0.040000  0.093333
# 50%   0.006667  0.080000  0.033333  0.060000  0.073333  0.133333  0.180000
# 100%  0.046667  0.053333  0.060000  0.086667  0.200000  0.226667  0.406667
#
#          10000
# 10%   0.306667
# 50%   0.673333
# 100%  0.700000
# # Translation (Y)
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.026667  0.066667  0.026667  0.060000  0.053333  0.053333  0.120000
# Medium  0.013333  0.033333  0.040000  0.073333  0.086667  0.080000  0.093333
# Large   0.020000  0.020000  0.000000  0.080000  0.060000  0.053333  0.093333
#
#            10000
# Small   0.626667
# Medium  0.600000
# Large   0.440000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.033333  0.053333  0.026667  0.053333  0.053333  0.040000  0.106667
# 50%   0.013333  0.020000  0.020000  0.040000  0.073333  0.040000  0.100000
# 100%  0.013333  0.046667  0.020000  0.120000  0.073333  0.106667  0.100000
#
#          10000
# 10%   0.520000
# 50%   0.506667
# 100%  0.640000
# # Flip
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.013333  0.033333  0.033333  0.060000  0.066667  0.046667  0.093333
# Medium  0.013333  0.020000  0.020000  0.053333  0.066667  0.100000  0.186667
# Large   0.013333  0.033333  0.040000  0.046667  0.020000  0.053333  0.053333
#
#            10000
# Small   0.500000
# Medium  0.866667
# Large   0.100000
# *Shift proportion vs. # of samples*
#       10        20        50        100       200       500       1000   \
# 10%    0.00  0.006667  0.026667  0.066667  0.053333  0.033333  0.080000
# 50%    0.02  0.046667  0.046667  0.033333  0.040000  0.093333  0.146667
# 100%   0.02  0.033333  0.020000  0.060000  0.060000  0.073333  0.106667
#
#          10000
# 10%   0.466667
# 50%   0.513333
# 100%  0.486667
# # All
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.033333  0.053333  0.020000  0.026667  0.066667  0.100000  0.133333
# Medium  0.020000  0.026667  0.026667  0.046667  0.033333  0.086667  0.060000
# Large   0.033333  0.066667  0.046667  0.073333  0.140000  0.133333  0.266667
#
#            10000
# Small   0.706667
# Medium  0.180000
# Large   0.433333
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.020000  0.053333  0.040000  0.040000  0.046667  0.106667  0.093333
# 50%   0.040000  0.046667  0.040000  0.046667  0.060000  0.053333  0.093333
# 100%  0.026667  0.046667  0.013333  0.060000  0.133333  0.160000  0.273333
#
#          10000
# 10%   0.340000
# 50%   0.366667
# 100%  0.613333

# %%
for shift in list_shifts[7:10]:
    display(Markdown(f"# {shift}"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.006667  0.013333  0.053333  0.186667  0.346667  0.433333
# Medium  0.013333  0.033333  0.066667  0.113333  0.206667  0.400000  0.546667
# Large   0.040000  0.060000  0.166667  0.326667  0.453333  0.673333  0.686667
#
#            10000
# Small   0.666667
# Medium  0.673333
# Large   0.806667
# *Shift proportion vs. # of samples*
#       10        20        50        100       200    500       1000      10000
# 10%    0.02  0.026667  0.026667  0.013333  0.020000   0.04  0.020000  0.146667
# 50%    0.02  0.046667  0.040000  0.113333  0.186667   0.50  0.646667  1.000000
# 100%   0.02  0.026667  0.180000  0.366667  0.640000   0.88  1.000000  1.000000
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.033333  0.020000  0.020000  0.053333  0.046667  0.006667  0.020000
# Medium  0.033333  0.046667  0.066667  0.086667  0.133333  0.213333  0.446667
# Large   0.006667  0.080000  0.180000  0.360000  0.493333  0.640000  0.700000
#
#            10000
# Small   0.006667
# Medium  0.666667
# Large   0.780000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.026667  0.040000  0.026667  0.026667  0.060000  0.033333  0.073333
# 50%   0.026667  0.026667  0.046667  0.106667  0.180000  0.326667  0.440000
# 100%  0.020000  0.080000  0.193333  0.366667  0.433333  0.500000  0.653333
#
#          10000
# 10%   0.113333
# 50%   0.673333
# 100%  0.666667
# # Translation (Y)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.006667  0.013333  0.053333  0.186667  0.346667  0.433333
# Medium  0.013333  0.033333  0.066667  0.113333  0.206667  0.400000  0.546667
# Large   0.040000  0.060000  0.166667  0.326667  0.453333  0.673333  0.686667
#
#            10000
# Small   0.666667
# Medium  0.673333
# Large   0.806667
# *Shift proportion vs. # of samples*
#       10        20        50        100       200    500       1000      10000
# 10%    0.02  0.026667  0.026667  0.013333  0.020000   0.04  0.020000  0.146667
# 50%    0.02  0.046667  0.040000  0.113333  0.186667   0.50  0.646667  1.000000
# 100%   0.02  0.026667  0.180000  0.366667  0.640000   0.88  1.000000  1.000000
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.033333  0.020000  0.020000  0.053333  0.046667  0.006667  0.020000
# Medium  0.033333  0.046667  0.066667  0.086667  0.133333  0.213333  0.446667
# Large   0.006667  0.080000  0.180000  0.360000  0.493333  0.640000  0.700000
#
#            10000
# Small   0.006667
# Medium  0.666667
# Large   0.780000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.026667  0.040000  0.026667  0.026667  0.060000  0.033333  0.073333
# 50%   0.026667  0.026667  0.046667  0.106667  0.180000  0.326667  0.440000
# 100%  0.020000  0.080000  0.193333  0.366667  0.433333  0.500000  0.653333
#
#          10000
# 10%   0.113333
# 50%   0.673333
# 100%  0.666667
# # Shear
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.006667  0.006667  0.013333  0.053333  0.186667  0.346667  0.433333
# Medium  0.013333  0.033333  0.066667  0.113333  0.206667  0.400000  0.546667
# Large   0.040000  0.060000  0.166667  0.326667  0.453333  0.673333  0.686667
#
#            10000
# Small   0.666667
# Medium  0.673333
# Large   0.806667
# *Shift proportion vs. # of samples*
#       10        20        50        100       200    500       1000      10000
# 10%    0.02  0.026667  0.026667  0.013333  0.020000   0.04  0.020000  0.146667
# 50%    0.02  0.046667  0.040000  0.113333  0.186667   0.50  0.646667  1.000000
# 100%   0.02  0.026667  0.180000  0.366667  0.640000   0.88  1.000000  1.000000
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.033333  0.020000  0.020000  0.053333  0.046667  0.006667  0.020000
# Medium  0.033333  0.046667  0.066667  0.086667  0.133333  0.213333  0.446667
# Large   0.006667  0.080000  0.180000  0.360000  0.493333  0.640000  0.700000
#
#            10000
# Small   0.006667
# Medium  0.666667
# Large   0.780000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.026667  0.040000  0.026667  0.026667  0.060000  0.033333  0.073333
# 50%   0.026667  0.026667  0.046667  0.106667  0.180000  0.326667  0.440000
# 100%  0.020000  0.080000  0.193333  0.366667  0.433333  0.500000  0.653333
#
#          10000
# 10%   0.113333
# 50%   0.673333
# 100%  0.666667

# %% [markdown]
# ### Gaussian shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = ["BBSDh"]
list_is_concepts = [False]

# %%
for shift, shift_str in zip(list_shifts[9:10], list_shift_str[9:10]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.013333  0.053333  0.013333  0.040000  0.060000  0.073333  0.100000
# Medium  0.006667  0.033333  0.060000  0.026667  0.053333  0.046667  0.120000
# Large   0.033333  0.100000  0.180000  0.366667  0.506667  0.560000  0.673333
#
#            10000
# Small   0.460000
# Medium  0.333333
# Large   0.666667
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.026667  0.013333  0.033333  0.040000  0.053333  0.060000  0.120000
# 50%   0.006667  0.073333  0.040000  0.100000  0.186667  0.233333  0.380000
# 100%  0.020000  0.100000  0.180000  0.293333  0.380000  0.386667  0.393333
#
#          10000
# 10%   0.293333
# 50%   0.566667
# 100%  0.600000

# %% [markdown]
# ## Detection accuracy vs test samples
#
# The figures plot how detection accuracy changes over different test (real-world) samples provided to each shift detector method. We compare performances of various methods.

# %%
list_shifts = ["Knockout", "Concept (Instance)", "Concept (Elevation)",
              "Concept (Azimuth)", "Concept (Category + Lighting)",
              "Translation (X)", "Translation (Y)", "Flip", "All", "Gaussian", "FGSM"]
list_labels = ["CBSDh", "BBSDh", "PCA", "SRP"]
list_is_concepts = [True, False, False, False]
list_shift_str = ["ko_task3", "instance_task3", "elevation_task3", "azimuth_task3", "category_lighting_task3",
                  "img_x_task3", "img_y_task3", "flip_task3", "all_task3", "gaussian_task3", "adversarial_task3"]

# %% [markdown]
# ### Knockout shift

# %%
for shift, shift_str in zip(list_shifts[:1], list_shift_str[:1]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout

# %% [markdown]
# ### Concept shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "instance", "elevation", "azimuth", "category_lighting",
                  "img_x", "img_y", "flip", "all", "gaussian", "adversarial"]

# %% [markdown]
# - Instance
# - Elevation
# - Azimuth
# - Category and lighting

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[1:5], list_shift_str_1[1:5], list_shift_str_2[1:5]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False, "smallnorb"))
        except:
            list_dict_results.append(load_result(shift_str1, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Instance)
# # Concept (Elevation)
# # Concept (Azimuth)
# # Concept (Category + Lighting)

# %% [markdown]
# ### Image shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "instance", "elevation", "azimuth", "category_lighting",
                  "img_x", "img_y", "flip", "all", "gaussian", "adversarial"]

# %% [markdown]
# - Translation (X)
# - Translation (Y)
# - Flip
# - All

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[5:9], list_shift_str_1[5:9], list_shift_str_2[5:9]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False, "smallnorb"))
        except:
            list_dict_results.append(load_result(shift_str1, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Translation (X)
# # Translation (Y)
# # Flip
# # All

# %% [markdown]
# ### Gaussian shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "instance", "elevation", "azimuth", "category_lighting",
                  "img_x", "img_y", "flip", "all", "gaussian", "adversarial"]

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[9:10], list_shift_str_1[9:10], list_shift_str_2[9:10]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False, "smallnorb"))
        except:
            list_dict_results.append(load_result(shift_str1, label, False, "smallnorb"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian

# %% [markdown]
# ## Barplot explanations
#
# The barplots depict the degree how each concept is affected by various type of shifts. Higher value indicates that the concept is more shifted relative to others.

# %%
# list_shifts = ["Knockout"]
# list_labels = ["CBSDs", "CBSDh"]
# list_shift_str = ["ko_task3"]
# list_dict_results = []
# for shift_str in list_shift_str:
#     temp = []
#     for label in list_labels:
#         temp.append(load_result(shift_str, label, False))
#     list_dict_results.append(temp)

# list_shift_intensity = [ShiftIntensity.Large]
# list_shift_prop = [1.0]
# list_test_sample = [1000, 10000]
# concept_names = ['category', 'instance', 'elevation', 'azimuth', 'lighting']

# %%
# for shift, dict_result in zip(list_shifts, list_dict_results):
#     display(Markdown(f"# {shift}"))
    
#     dict_cbsds = dict_result[0]
#     dict_cbsdh = dict_result[1]
    
#     barplot_test_statistics(dict_cbsds, dict_cbsdh,
#                            concept_names, list_shift_intensity,
#                            list_shift_prop, list_test_sample)
