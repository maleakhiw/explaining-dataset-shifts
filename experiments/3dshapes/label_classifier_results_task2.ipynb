# %% [markdown]
# # Label classifier (3dshapes): results
#
# ## Task 2
#
# **Author**: Maleakhi A. Wijaya
# **Description**: This notebook contains code used to visualise experimentation results for the 3dshapes dataset. In this file, we focus on task 2: end task to predict the combination of shape and scale of the 3dshapes.

# %%
# Load utilities functions
# %run ../../scripts/constants.py
# %run ../../scripts/3dshapes_utils.py
# %run ../../scripts/shift_applicator.py
# %run ../../scripts/shift_dimensionality_reductor.py
# %run ../../scripts/experiment_utils.py
# %run ../../scripts/shift_statistical_test.py

# %% [markdown]
# ## Tables
#
# The tables depict detection accuracy for different sample number against varying shift intensities and shift proportions.

# %%
list_shifts = ["Knockout", "Concept (Floor)", "Concept (Wall)",
              "Concept (Object + Scale)", "Rotation", "Shear", "Flip", "All", "Gaussian", "FGSM"]
list_labels = ["CBSDs", "CBSDh", "BBSDs", "BBSDh", "PCA", "SRP"]
list_is_concepts = [True, True, False, False, False, False]
list_shift_str = ["ko_task2", "floor_task2", "wall_task2", "object_scale_task2", 
                  "rotation_task2", "shear_task2", "flip_task2", "all_task2", 
                  "gaussian_task2", "adversarial_task2"]

# %% [markdown]
# ### Knockout shift

# %%
for shift, shift_str in zip(list_shifts[:1], list_shift_str[:1]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "3dshapes"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout
# ## Method: CBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500    1000   \
# Small   0.100000  0.033333  0.066667  0.066667  0.100000  0.033333    0.0
# Medium  0.033333  0.066667  0.033333  0.100000  0.033333  0.066667    0.0
# Large   0.166667  0.000000  0.000000  0.133333  0.100000  0.100000    0.0
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10     20        50        100       200       500    1000   10000
# 10%   0.100000    0.0  0.066667  0.133333  0.033333  0.033333    0.0    0.0
# 50%   0.133333    0.1  0.033333  0.133333  0.066667  0.033333    0.0    0.0
# 100%  0.066667    0.0  0.000000  0.033333  0.133333  0.133333    0.0    0.0
# ## Method: CBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.166667  0.233333  0.200000  0.166667  0.200000  0.266667  0.133333
# Medium  0.100000  0.266667  0.200000  0.233333  0.366667  0.200000  0.200000
# Large   0.233333  0.233333  0.233333  0.166667  0.400000  0.233333  0.566667
#
#            10000
# Small   0.366667
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#       10        20        50        100       200       500       1000   \
# 10%     0.2  0.400000  0.166667  0.166667  0.266667  0.166667  0.400000
# 50%     0.2  0.266667  0.266667  0.233333  0.333333  0.300000  0.233333
# 100%    0.1  0.066667  0.200000  0.166667  0.366667  0.233333  0.266667
#
#          10000
# 10%   0.800000
# 50%   0.733333
# 100%  0.833333
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50     100       200       500    1000   10000
# Small   0.000000  0.100000  0.033333    0.0  0.000000  0.000000    0.0    0.0
# Medium  0.000000  0.000000  0.033333    0.0  0.000000  0.033333    0.0    0.0
# Large   0.066667  0.066667  0.000000    0.0  0.033333  0.100000    0.0    0.0
# *Shift proportion vs. # of samples*
#          10        20        50     100       200       500    1000   10000
# 10%   0.066667  0.066667  0.000000    0.0  0.000000  0.033333    0.0    0.0
# 50%   0.000000  0.066667  0.033333    0.0  0.033333  0.100000    0.0    0.0
# 100%  0.000000  0.033333  0.033333    0.0  0.000000  0.000000    0.0    0.0
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.000000  0.022222  0.000000  0.088889  0.000000  0.066667  0.088889
# Medium  0.000000  0.000000  0.022222  0.022222  0.000000  0.000000  0.022222
# Large   0.022222  0.022222  0.022222  0.022222  0.088889  0.288889  1.000000
#
#         10000
# Small     0.0
# Medium    1.0
# Large     1.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.000000  0.000000  0.022222  0.044444  0.044444  0.111111  0.355556
# 50%   0.000000  0.022222  0.022222  0.044444  0.022222  0.088889  0.377778
# 100%  0.022222  0.022222  0.000000  0.044444  0.022222  0.155556  0.377778
#
#          10000
# 10%   0.666667
# 50%   0.666667
# 100%  0.666667
# ## Method: PCA
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500    1000   \
# Small   0.000000  0.066667  0.044444  0.044444  0.088889  0.133333    0.0
# Medium  0.088889  0.044444  0.044444  0.022222  0.022222  0.022222    0.0
# Large   0.022222  0.022222  0.066667  0.088889  0.044444  0.066667    0.0
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500    1000   10000
# 10%   0.044444  0.044444  0.044444  0.044444  0.044444  0.044444    0.0    0.0
# 50%   0.000000  0.044444  0.088889  0.044444  0.044444  0.066667    0.0    0.0
# 100%  0.066667  0.044444  0.022222  0.066667  0.066667  0.111111    0.0    0.0
# ## Method: SRP
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500    1000   \
# Small   0.044444  0.088889  0.044444  0.044444  0.044444  0.044444    0.0
# Medium  0.066667  0.066667  0.022222  0.022222  0.044444  0.022222    0.0
# Large   0.000000  0.066667  0.022222  0.044444  0.000000  0.044444    0.0
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500    1000   10000
# 10%   0.000000  0.066667  0.000000  0.022222  0.000000  0.044444    0.0    0.0
# 50%   0.088889  0.088889  0.044444  0.022222  0.066667  0.022222    0.0    0.0
# 100%  0.022222  0.066667  0.044444  0.066667  0.022222  0.044444    0.0    0.0

# %% [markdown]
# ### Concept shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = [ "BBSDs", "BBSDh"]
list_is_concepts = [False, False]

# %% [markdown]
# - Floor
# - Wall
# - Object + Scale

# %%
for shift, shift_str in zip(list_shifts[1:4], list_shift_str[1:4]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "3dshapes"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Floor)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.033333  0.033333  0.033333  0.033333  0.066667  0.033333  0.000000
# Medium  0.066667  0.000000  0.100000  0.033333  0.000000  0.000000  0.000000
# Large   0.000000  0.033333  0.000000  0.133333  0.100000  0.166667  0.466667
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.000000  0.066667  0.066667  0.100000  0.000000  0.066667  0.133333
# 50%   0.033333  0.000000  0.033333  0.066667  0.100000  0.066667  0.133333
# 100%  0.066667  0.000000  0.033333  0.033333  0.066667  0.066667  0.200000
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.000000  0.155556  0.044444  0.088889  0.044444  0.022222  0.044444
# Medium  0.000000  0.066667  0.044444  0.044444  0.044444  0.066667  0.022222
# Large   0.088889  0.066667  0.133333  0.111111  0.066667  0.022222  0.066667
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.000000  0.111111  0.044444  0.022222  0.000000  0.066667  0.066667
# 50%   0.044444  0.044444  0.066667  0.111111  0.022222  0.022222  0.000000
# 100%  0.044444  0.133333  0.111111  0.111111  0.133333  0.022222  0.066667
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# # Concept (Wall)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500    1000   \
# Small   0.033333  0.000000  0.066667  0.100000  0.033333  0.033333    0.0
# Medium  0.000000  0.066667  0.033333  0.033333  0.000000  0.033333    0.0
# Large   0.066667  0.100000  0.066667  0.000000  0.000000  0.033333    0.0
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500    1000   10000
# 10%   0.000000  0.066667  0.033333  0.033333  0.000000  0.033333    0.0    0.0
# 50%   0.066667  0.033333  0.100000  0.066667  0.000000  0.033333    0.0    0.0
# 100%  0.033333  0.066667  0.033333  0.033333  0.033333  0.033333    0.0    0.0
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.088889  0.066667  0.044444  0.111111  0.044444  0.111111  0.088889
# Medium  0.044444  0.044444  0.111111  0.044444  0.000000  0.022222  0.111111
# Large   0.066667  0.066667  0.044444  0.022222  0.088889  0.000000  0.044444
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.066667  0.022222  0.088889  0.044444  0.000000  0.044444  0.088889
# 50%   0.022222  0.111111  0.088889  0.066667  0.088889  0.022222  0.088889
# 100%  0.111111  0.044444  0.022222  0.066667  0.044444  0.066667  0.066667
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# # Concept (Object + Scale)
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#         10        20        50        100       200       500       1000   \
# Small     0.0  0.000000  0.066667  0.033333  0.033333  0.033333  0.000000
# Medium    0.0  0.100000  0.066667  0.066667  0.000000  0.000000  0.000000
# Large     0.0  0.033333  0.066667  0.066667  0.166667  0.733333  0.833333
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#       10        20        50        100       200       500       1000   10000
# 10%     0.0  0.000000  0.033333  0.066667  0.066667  0.266667  0.300000    0.0
# 50%     0.0  0.133333  0.066667  0.066667  0.100000  0.166667  0.233333    0.0
# 100%    0.0  0.000000  0.100000  0.033333  0.033333  0.333333  0.300000    0.0
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.000000  0.066667  0.044444  0.044444  0.022222  0.022222  0.022222
# Medium  0.000000  0.022222  0.022222  0.000000  0.022222  0.200000  0.577778
# Large   0.044444  0.022222  0.155556  0.222222  0.755556  1.000000  1.000000
#
#         10000
# Small     0.0
# Medium    1.0
# Large     1.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.022222  0.044444  0.066667  0.066667  0.311111  0.400000  0.577778
# 50%   0.000000  0.066667  0.066667  0.111111  0.244444  0.400000  0.488889
# 100%  0.022222  0.000000  0.088889  0.088889  0.244444  0.422222  0.533333
#
#          10000
# 10%   0.666667
# 50%   0.666667
# 100%  0.666667

# %% [markdown]
# ### Image shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = [ "BBSDs", "BBSDh"]
list_is_concepts = [False, False]

# %% [markdown]
# - Rotation
# - Shear
# - Flip
# - All

# %%
for shift, shift_str in zip(list_shifts[4:8], list_shift_str[4:8]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, 
                                             label, False, "3dshapes"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Rotation
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.466667  0.666667  0.700000  0.766667  0.800000  0.966667  0.666667
# Medium  0.666667  0.700000  0.700000  0.833333  0.866667  1.000000  0.666667
# Large   0.666667  0.700000  0.733333  0.833333  0.933333  1.000000  0.666667
#
#         10000
# Small     1.0
# Medium    1.0
# Large     1.0
# *Shift proportion vs. # of samples*
#          10        20        50        100    200       500    1000   10000
# 10%   0.033333  0.066667  0.133333  0.433333    0.6  0.966667    0.0    1.0
# 50%   0.800000  1.000000  1.000000  1.000000    1.0  1.000000    1.0    1.0
# 100%  0.966667  1.000000  1.000000  1.000000    1.0  1.000000    1.0    1.0
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.000000  0.022222  0.088889  0.155556  0.288889  0.533333  0.644444
# Medium  0.266667  0.288889  0.511111  0.555556  0.666667  0.733333  0.777778
# Large   0.222222  0.355556  0.555556  0.666667  0.733333  0.911111  0.977778
#
#            10000
# Small   0.666667
# Medium  1.000000
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.022222  0.066667  0.044444  0.044444  0.066667  0.355556  0.444444
# 50%   0.088889  0.133333  0.400000  0.555556  0.733333  0.822222  0.955556
# 100%  0.377778  0.466667  0.711111  0.777778  0.888889  1.000000  1.000000
#
#          10000
# 10%   0.666667
# 50%   1.000000
# 100%  1.000000
# # Shear
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500    1000   \
# Small   0.000000  0.000000  0.000000  0.033333  0.033333  0.000000    0.0
# Medium  0.000000  0.033333  0.000000  0.066667  0.033333  0.033333    0.0
# Large   0.033333  0.033333  0.066667  0.033333  0.033333  0.000000    0.0
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500    1000   10000
# 10%   0.000000  0.033333  0.000000  0.033333  0.000000  0.000000    0.0    0.0
# 50%   0.033333  0.033333  0.033333  0.066667  0.066667  0.000000    0.0    0.0
# 100%  0.000000  0.000000  0.033333  0.033333  0.033333  0.033333    0.0    0.0
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.133333  0.066667  0.088889  0.111111  0.088889  0.022222  0.066667
# Medium  0.066667  0.088889  0.044444  0.111111  0.066667  0.022222  0.066667
# Large   0.088889  0.066667  0.066667  0.022222  0.088889  0.044444  0.022222
#
#         10000
# Small     0.0
# Medium    0.0
# Large     0.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.133333  0.066667  0.022222  0.111111  0.088889  0.066667  0.044444
# 50%   0.088889  0.066667  0.066667  0.111111  0.022222  0.000000  0.044444
# 100%  0.066667  0.088889  0.111111  0.022222  0.133333  0.022222  0.066667
#
#       10000
# 10%     0.0
# 50%     0.0
# 100%    0.0
# # Flip
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.000000  0.000000  0.033333  0.033333  0.000000  0.066667  0.000000
# Medium  0.266667  0.400000  0.633333  0.666667  0.733333  0.766667  0.666667
# Large   0.500000  0.633333  0.700000  0.766667  0.800000  1.000000  0.666667
#
#         10000
# Small     0.0
# Medium    1.0
# Large     1.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.033333  0.000000  0.033333  0.100000  0.200000  0.433333  0.000000
# 50%   0.166667  0.433333  0.666667  0.666667  0.666667  0.700000  0.666667
# 100%  0.566667  0.600000  0.666667  0.700000  0.666667  0.700000  0.666667
#
#          10000
# 10%   0.666667
# 50%   0.666667
# 100%  0.666667
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.066667  0.022222  0.066667  0.066667  0.044444  0.066667  0.000000
# Medium  0.088889  0.066667  0.244444  0.333333  0.555556  0.688889  0.755556
# Large   0.400000  0.600000  0.644444  0.733333  0.755556  0.977778  1.000000
#
#         10000
# Small     0.0
# Medium    1.0
# Large     1.0
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.066667  0.066667  0.066667  0.088889  0.155556  0.400000  0.422222
# 50%   0.133333  0.266667  0.400000  0.355556  0.488889  0.666667  0.666667
# 100%  0.355556  0.355556  0.488889  0.688889  0.711111  0.666667  0.666667
#
#          10000
# 10%   0.666667
# 50%   0.666667
# 100%  0.666667
# # All
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#            10     20        50        100       200    500       1000   10000
# Small   0.666667    0.7  0.800000  0.833333  0.966667    1.0  0.666667    1.0
# Medium  0.666667    0.7  0.733333  0.766667  0.966667    1.0  0.666667    1.0
# Large   0.666667    0.7  0.733333  0.766667  0.966667    1.0  0.666667    1.0
# *Shift proportion vs. # of samples*
#          10     20        50        100    200    500    1000   10000
# 10%   0.033333    0.1  0.266667  0.366667    0.9    1.0    0.0    1.0
# 50%   0.966667    1.0  1.000000  1.000000    1.0    1.0    1.0    1.0
# 100%  1.000000    1.0  1.000000  1.000000    1.0    1.0    1.0    1.0
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.111111  0.355556  0.555556  0.533333  0.688889  0.711111  0.711111
# Medium  0.222222  0.466667  0.666667  0.755556  0.733333  0.822222  0.977778
# Large   0.377778  0.511111  0.666667  0.733333  0.777778  0.955556  1.000000
#
#         10000
# Small     1.0
# Medium    1.0
# Large     1.0
# *Shift proportion vs. # of samples*
#          10        20        50        100    200       500       1000   10000
# 10%   0.000000  0.022222  0.088889  0.155556    0.2  0.488889  0.688889    1.0
# 50%   0.244444  0.422222  0.800000  0.866667    1.0  1.000000  1.000000    1.0
# 100%  0.466667  0.888889  1.000000  1.000000    1.0  1.000000  1.000000    1.0

# %% [markdown]
# ### Gaussian shift

# %%
# All the methods results are similar to Task 1 as concept shift does not depend on the end task.
list_labels = [ "BBSDs", "BBSDh"]
list_is_concepts = [False, False]

# %%
for shift, shift_str in zip(list_shifts[8:9], list_shift_str[8:9]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False, "3dshapes"))
    summary_tables(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian
# ## Method: BBSDs
# *Shift intensities vs. # of samples*
#         10        20        50        100       200       500       1000   \
# Small     0.0  0.033333  0.033333  0.000000  0.066667  0.000000  0.000000
# Medium    0.0  0.066667  0.100000  0.166667  0.133333  0.366667  0.000000
# Large     0.7  0.733333  0.700000  0.800000  0.833333  1.000000  0.666667
#
#            10000
# Small   0.000000
# Medium  0.666667
# Large   1.000000
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.033333  0.100000  0.066667  0.166667  0.233333  0.333333  0.000000
# 50%   0.333333  0.366667  0.366667  0.366667  0.333333  0.433333  0.333333
# 100%  0.333333  0.366667  0.400000  0.433333  0.466667  0.600000  0.333333
#
#          10000
# 10%   0.333333
# 50%   0.666667
# 100%  0.666667
# ## Method: BBSDh
# *Shift intensities vs. # of samples*
#            10        20        50        100       200       500       1000   \
# Small   0.155556  0.066667  0.088889  0.022222  0.088889  0.044444  0.000000
# Medium  0.022222  0.022222  0.044444  0.044444  0.022222  0.000000  0.022222
# Large   0.066667  0.044444  0.066667  0.111111  0.066667  0.422222  0.488889
#
#            10000
# Small   0.000000
# Medium  0.000000
# Large   0.666667
# *Shift proportion vs. # of samples*
#          10        20        50        100       200       500       1000   \
# 10%   0.022222  0.088889  0.044444  0.022222  0.066667  0.022222  0.000000
# 50%   0.111111  0.022222  0.111111  0.111111  0.000000  0.155556  0.155556
# 100%  0.111111  0.022222  0.044444  0.044444  0.111111  0.288889  0.355556
#
#          10000
# 10%   0.000000
# 50%   0.333333
# 100%  0.333333

# %% [markdown]
# ## Detection accuracy vs test samples
#
# The figures plot how detection accuracy changes over different test (real-world) samples provided to each shift detector method. We compare performances of various methods.

# %%
list_shifts = ["Knockout", "Concept (Floor)", "Concept (Wall)",
              "Concept (Object + Scale)", "Rotation", "Shear", "Flip", "All", "Gaussian", "FGSM"]
list_labels = ["CBSDs", "CBSDh", "BBSDs", "BBSDh", "PCA", "SRP"]
list_is_concepts = [True, True, False, False, False, False]
list_shift_str = ["ko_task2", "floor_task2", "wall_task2", "object_scale_task2", 
                  "rotation_task2", "shear_task2", "flip_task2", "all_task2", 
                  "gaussian_task2", "adversarial_task2"]

# %% [markdown]
# ### Knockout shift

# %%
for shift, shift_str in zip(list_shifts[:1], list_shift_str[:1]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        list_dict_results.append(load_result(shift_str, label, False))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Knockout

# %% [markdown]
# ### Concept shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "floor", "wall", "object_scale", "rotation", 
                  "shear", "flip", "all", "gaussian", "adversarial"]

# %% [markdown]
# - Floor
# - Wall
# - Object + Scale

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[1:4], list_shift_str_1[1:4], list_shift_str_2[1:4]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False, "3dshapes"))
        except:
            list_dict_results.append(load_result(shift_str1, label, False, "3dshapes"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Concept (Floor)
# # Concept (Wall)
# # Concept (Object + Scale)

# %% [markdown]
# ### Image shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "floor", "wall", "object_scale", "rotation", 
                  "shear", "flip", "all", "gaussian", "adversarial"]

# %% [markdown]
# - Rotation
# - Shear
# - Flip
# - All

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[4:8], list_shift_str_1[4:8], list_shift_str_2[4:8]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False, "3dshapes"))
        except:
            list_dict_results.append(load_result(shift_str1, label, False, "3dshapes"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Rotation
# # Shear
# # Flip
# # All

# %% [markdown]
# ### Gaussian shift

# %%
list_shift_str_2 = list_shift_str
list_shift_str_1 = ["ko", "floor", "wall", "object_scale", "rotation", 
                  "shear", "flip", "all", "gaussian", "adversarial"]

# %%
for shift, shift_str1, shift_str2 in zip(list_shifts[8:9], list_shift_str_1[8:9], list_shift_str_2[8:9]):
    display(Markdown(f"# {shift}"))
    list_dict_results = []
    for label in list_labels:
        try:
            list_dict_results.append(load_result(shift_str2, label, False, "3dshapes"))
        except:
            list_dict_results.append(load_result(shift_str1, label, False, "3dshapes"))
    plot_accuracy_vs_samples(list_dict_results, list_labels, list_is_concepts)
# Out:
# # Gaussian

# %% [markdown]
# ## Barplot explanations
#
# The barplots depict the degree how each concept is affected by various type of shifts. Higher value indicates that the concept is more shifted relative to others.

# %%
list_shifts = ["Knockout"]
list_labels = ["CBSDs", "CBSDh"]
list_shift_str = ["ko_task2"]
list_dict_results = []
for shift_str in list_shift_str:
    temp = []
    for label in list_labels:
        temp.append(load_result(shift_str, label, False, "3dshapes"))
    list_dict_results.append(temp)

list_shift_intensity = [ShiftIntensity.Medium, ShiftIntensity.Large]
list_shift_prop = [1.0]
list_test_sample = [1000, 10000]
concept_names = ["floor", "wall", "object", "scale", "shape", "orientation"]

# %%
for shift, dict_result in zip(list_shifts, list_dict_results):
    display(Markdown(f"# {shift}"))
    
    dict_cbsds = dict_result[0]
    dict_cbsdh = dict_result[1]
    
    barplot_test_statistics(dict_cbsds, dict_cbsdh,
                           concept_names, list_shift_intensity,
                           list_shift_prop, list_test_sample)
# Out:
# # Knockout
# Shift intensity: Medium
# Shift proportion: 1.0
# # test samples: 1000
# Shift intensity: Medium
# Shift proportion: 1.0
# # test samples: 10000
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 1000
# Shift intensity: Large
# Shift proportion: 1.0
# # test samples: 10000
